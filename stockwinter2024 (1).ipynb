# %%
from jupyter_auth_login import login

# Perform login
login_response = login(
    username="nandarohan442@gmail.com",
    password="Ron1506313015$",
    by_sms=True,
    store_session=False
)

# Save token to file
with open("robinhood_token.txt", "w") as f:
    f.write(login_response["access_token"])

print("✅ Token saved to robinhood_token.txt")
# Out:
# Verification workflow required. Please check your Robinhood app for instructions.
# Waiting for challenge to be validated
# 5.088316440582275
# Waiting for challenge to be validated
# 10.18752670288086
# Waiting for challenge to be validated
# 15.273086309432983
# ✅ Token saved to robinhood_token.txt

# %%
import requests
import pandas as pd
from datetime import datetime
import os

# Load token from file
def load_token_from_file(file_path="robinhood_token.txt"):
    if os.path.exists(file_path):
        with open(file_path, "r") as f:
            return f.read().strip()
    return None

# Fetch and save stock data
def fetch_and_save_stock_data(token, output_file="my_stock_data.xlsx"):
    url = "https://api.robinhood.com/positions/"
    headers = {"Authorization": f"Bearer {token}"}
    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        print("Error fetching stock data:", response.text)
        return

    positions = response.json().get("results", [])
    stock_data = []

    # Get the current timestamp
    fetch_time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

    for position in positions:
        if float(position["quantity"]) > 0:  # Only fetch open positions
            instrument_url = position["instrument"]
            instrument_data = requests.get(instrument_url, headers=headers).json()

            symbol = instrument_data["symbol"]
            quantity = float(position["quantity"])
            average_buy_price = float(position["average_buy_price"])
            quote_url = f"https://api.robinhood.com/quotes/{symbol}/"
            current_price = float(requests.get(quote_url, headers=headers).json()["last_trade_price"])

            market_value = current_price * quantity
            profit_loss = (current_price - average_buy_price) * quantity

            stock_data.append({
                "Timestamp": fetch_time,  # Add the timestamp
                "Symbol": symbol,
                "Quantity": quantity,
                "Average Buy Price": average_buy_price,
                "Current Price": current_price,
                "Market Value": market_value,
                "Profit/Loss": profit_loss
            })

    df = pd.DataFrame(stock_data)
    df.to_excel(output_file, index=False)
    print(f"Stock data saved to {output_file}")

# Use token to fetch data
token = load_token_from_file()
if token:
    fetch_and_save_stock_data(token)
else:
    print("No token found. Please log in first.")
# Out:
# Stock data saved to my_stock_data.xlsx

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\gargi\anaconda3\lib\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\gargi\anaconda3\lib\site-packages (from tqdm) (0.4.6)

# %%
import requests
import pandas as pd
import os
import time
from tqdm import tqdm  # ✅ Add this

# Function to fetch all tickers from Robinhood
def fetch_all_tickers_from_robinhood():
    classification_map = {
        "stock": "Equity",
        "etf": "Exchange-Traded Fund",
        "warrant": "Derivative",
        "mutual_fund": "Mutual Fund",
        "bond": "Fixed Income",
    }
    sector_classifications = {
        "software": "Technology",
        "hardware": "Technology",
        "semiconductors": "Technology",
        "it services": "Technology",
        "pharmaceuticals": "Healthcare",
        "biotech": "Healthcare",
        "medical devices": "Healthcare",
        "healthcare services": "Healthcare",
        "banks": "Financials",
        "insurance companies": "Financials",
        "investment firms": "Financials",
        "reits": "Real Estate",
        "retail": "Consumer Discretionary",
        "automotive": "Consumer Discretionary",
        "travel": "Consumer Discretionary",
        "entertainment": "Consumer Discretionary",
        "food": "Consumer Staples",
        "beverages": "Consumer Staples",
        "personal products": "Consumer Staples",
        "household goods": "Consumer Staples",
        "oil": "Energy",
        "gas": "Energy",
        "renewable energy": "Energy",
        "energy equipment": "Energy",
        "manufacturing": "Industrials",
        "construction": "Industrials",
        "aerospace": "Industrials",
        "logistics": "Industrials",
        "mining": "Materials",
        "chemicals": "Materials",
        "construction materials": "Materials",
        "forestry products": "Materials",
        "electricity": "Utilities",
        "water": "Utilities",
        "natural gas": "Utilities",
        "renewable utilities": "Utilities",
        "commercial reits": "Real Estate",
        "residential reits": "Real Estate",
        "property management": "Real Estate",
        "telecommunications": "Communication Services",
        "media": "Communication Services",
        "internet services": "Communication Services",
        "cloud services": "Technology",
        "ai": "Technology"
    }

    url = "https://api.robinhood.com/instruments/"
    tickers = []
    next_url = url

    print("⏳ Fetching data pages from Robinhood...")
    with tqdm(desc="Pages fetched", unit="page") as pbar:
        while next_url:
            try:
                response = requests.get(next_url)
                response.raise_for_status()
                data = response.json()
                tickers.extend([
                    {
                        "Ticker": item['symbol'],
                        "Name": item['name'],
                        "Type": item['type'],
                        "Classification": classification_map.get(item['type'], "Unknown"),
                        "Sector": sector_classifications.get(item['name'].lower(), "Unknown"),
                        "Tradeable": item['tradeable']
                    } for item in data.get('results', [])
                ])
                next_url = data.get('next')
                pbar.update(1)  # ✅ increment the loading bar

                if next_url:
                    time.sleep(1)  # Respect rate limits
            except requests.exceptions.RequestException as e:
                print(f"❌ Error fetching tickers: {e}")
                break

    return tickers

# Save tickers to an Excel file
def save_tickers_to_excel(tickers, filename=None):
    if filename is None:
        downloads_path = os.path.join(os.path.expanduser("~"), "Downloads")
        filename = os.path.join(downloads_path, "robinhood_tickers.xlsx")
    df = pd.DataFrame(tickers)
    df = df[df['Tradeable'] == True]  # Filter out non-tradable tickers
    df.to_excel(filename, index=False)
    print(f"✅ Tickers saved to {filename}")

# Main logic
def main():
    print("🚀 Starting ticker scrape from Robinhood...")
    tickers = fetch_all_tickers_from_robinhood()

    if not tickers:
        print("⚠️ No tickers fetched. Exiting...")
        return

    save_tickers_to_excel(tickers)

if __name__ == "__main__":
    main()
# Out:
# 🚀 Starting ticker scrape from Robinhood...
# ⏳ Fetching data pages from Robinhood...
# Pages fetched: 250page [05:29,  1.30s/page]
# ✅ Tickers saved to C:\Users\gargi\Downloads\robinhood_tickers.xlsx

# %%
pip install yfinance pandas openpyxl
# Out:
# Requirement already satisfied: yfinance in c:\users\gargi\anaconda3\lib\site-packages (0.2.38)
# Requirement already satisfied: pandas in c:\users\gargi\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: openpyxl in c:\users\gargi\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\gargi\anaconda3\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\gargi\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\gargi\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\gargi\anaconda3\lib\site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\gargi\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\gargi\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\gargi\anaconda3\lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\gargi\anaconda3\lib\site-packages (from yfinance) (3.17.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\gargi\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\gargi\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gargi\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gargi\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: et-xmlfile in c:\users\gargi\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gargi\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\gargi\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\gargi\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gargi\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gargi\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gargi\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gargi\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import yfinance as yf
import time
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
from IPython.display import Javascript, display

# --- Load tickers, filtering only stocks ---
def load_tickers_from_excel(file_path):
    try:
        df = pd.read_excel(file_path)
        stock_df = df[
            df['Type'].astype(str).str.lower().str.contains('stock', na=False) &
            (df['Tradeable'] == True)
        ]
        print("🧠 Sample stock tickers:", stock_df['Ticker'].head(10).tolist())
        return stock_df['Ticker'].tolist()
    except Exception as e:
        print(f"❌ Error loading tickers from Excel: {e}")
        return []

# --- Clean ticker symbols ---
def clean_tickers(tickers):
    return [str(ticker).strip().upper() for ticker in tickers if isinstance(ticker, str) and ticker.strip()]

# --- Validate a single ticker with 7-day lookback ---
def validate_ticker(ticker):
    try:
        stock = yf.Ticker(ticker)
        hist = stock.history(period="7d")  # ✅ Looser check (works on weekends)
        if not hist.empty:
            return ticker, True
    except Exception:
        pass
    return ticker, False

# --- Validate using parallel threads ---
def validate_tickers_parallel(tickers, max_workers=10):
    valid_tickers = []
    invalid_tickers = []

    print(f"🔍 Validating {len(tickers)} tickers using {max_workers} threads...")
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(validate_ticker, ticker): ticker for ticker in tickers}
        for future in tqdm(as_completed(futures), total=len(futures), desc="Validation progress"):
            ticker, is_valid = future.result()
            if is_valid:
                valid_tickers.append(ticker)
            else:
                invalid_tickers.append(ticker)

    print(f"✅ Valid tickers: {len(valid_tickers)}, ❌ Invalid tickers: {len(invalid_tickers)}")
    return valid_tickers, invalid_tickers

# --- Save filtered tickers to Excel ---
def save_filtered_tickers(valid_tickers, invalid_tickers, output_file):
    valid_df = pd.DataFrame({'Valid Tickers': valid_tickers})
    invalid_df = pd.DataFrame({'Invalid Tickers': invalid_tickers})

    with pd.ExcelWriter(output_file) as writer:
        valid_df.to_excel(writer, sheet_name='Valid Tickers', index=False)
        invalid_df.to_excel(writer, sheet_name='Invalid Tickers', index=False)

    print(f"📁 Filtered tickers saved to {output_file}")

# --- Run next cell in Jupyter Notebook ---
def run_next_cell():
    try:
        display(Javascript('IPython.notebook.execute_cell_range(IPython.notebook.get_selected_index()+1, IPython.notebook.get_selected_index()+2)'))
    except:
        print("⚠️ Unable to run next cell — likely not in classic Jupyter Notebook.")

# --- Main execution function ---
def main():
    input_file = "robinhood_tickers.xlsx"
    output_file = "validated_tickers.xlsx"

    print("📥 Loading tickers from Excel...")
    tickers = load_tickers_from_excel(input_file)

    if not tickers:
        print("⚠️ No tickers found. Exiting...")
        return

    print("🧹 Cleaning ticker list...")
    tickers = clean_tickers(tickers)

    if not tickers:
        print("⚠️ No valid tickers after cleaning. Exiting...")
        return

    valid_tickers, invalid_tickers = validate_tickers_parallel(tickers)

    print("💾 Saving results...")
    save_filtered_tickers(valid_tickers, invalid_tickers, output_file)

    print("✅ Done. Moving to next cell (if supported)...")
    run_next_cell()

# --- Run the pipeline ---
if __name__ == "__main__":
    main()
# Out:
# 📥 Loading tickers from Excel...
# 🧠 Sample stock tickers: ['JCSE', 'ARTV', 'ALTS', 'SNWV', 'WRLD', 'CSAI', 'CE', 'CRH', 'GLNG', 'TSQ']
# 🧹 Cleaning ticker list...
# 🔍 Validating 5185 tickers using 10 threads...
# Failed to get ticker 'SNWV' reason: Expecting value: line 1 column 1 (char 0)                 | 0/5185 [00:00<?, ?it/s]
# ALTS: No price data found, symbol may be delisted (period=7d)
# ARTV: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'CSAI' reason: Expecting value: line 1 column 1 (char 0)         | 1/5185 [00:00<57:10,  1.51it/s]
# WRLD: No price data found, symbol may be delisted (period=7d)
# JCSE: No price data found, symbol may be delisted (period=7d)
# CE: No price data found, symbol may be delisted (period=7d)
# GLNG: No price data found, symbol may be delisted (period=7d)
# CRH: No price data found, symbol may be delisted (period=7d)                          | 6/5185 [00:01<12:25,  6.95it/s]
# SNWV: No price data found, symbol may be delisted (period=7d)
# TSQ: No price data found, symbol may be delisted (period=7d)
# APXIF: No price data found, symbol may be delisted (period=7d)
# LGF.B: No price data found, symbol may be delisted (period=7d)                       | 10/5185 [00:01<10:04,  8.56it/s]
# CSAI: No price data found, symbol may be delisted (period=7d)
# J: No price data found, symbol may be delisted (period=7d)
# YOSH: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'NXUR' reason: Expecting value: line 1 column 1 (char 0)
# SWKH: No price data found, symbol may be delisted (period=7d)
# COLL: No price data found, symbol may be delisted (period=7d)
# DDS: No price data found, symbol may be delisted (period=7d)                         | 16/5185 [00:01<07:39, 11.24it/s]
# VISL: No price data found, symbol may be delisted (period=7d)
# VSH: No price data found, symbol may be delisted (period=7d)
# CVGW: No price data found, symbol may be delisted (period=7d)
# Validation progress:   0%|▏                                                          | 20/5185 [00:02<07:45, 11.10it/s]MCHX: No price data found, symbol may be delisted (period=7d)
# IMAX: No price data found, symbol may be delisted (period=7d)
# NXUR: No price data found, symbol may be delisted (period=7d)
# NPO: No price data found, symbol may be delisted (period=7d)
# RVSB: No price data found, symbol may be delisted (period=7d)
# PMTS: No price data found, symbol may be delisted (period=7d)
# MSN: No price data found, symbol may be delisted (period=7d)                         | 26/5185 [00:02<06:44, 12.74it/s]
# STNG: No price data found, symbol may be delisted (period=7d)
# ACHV: No price data found, symbol may be delisted (period=7d)
# LXEO: No price data found, symbol may be delisted (period=7d)
# MGNX: No price data found, symbol may be delisted (period=7d)                        | 30/5185 [00:02<06:50, 12.56it/s]
# AMP: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'EVCO' reason: Expecting value: line 1 column 1 (char 0)
# TELO: No price data found, symbol may be delisted (period=7d)
# TFSL: No price data found, symbol may be delisted (period=7d)
# NRG: No price data found, symbol may be delisted (period=7d)
# BOKF: No price data found, symbol may be delisted (period=7d)                        | 35/5185 [00:03<06:39, 12.88it/s]
# LPCN: No price data found, symbol may be delisted (period=7d)
# TNET: No price data found, symbol may be delisted (period=7d)
# ESI: No price data found, symbol may be delisted (period=7d)
# TLYS: No price data found, symbol may be delisted (period=7d)
# EVCO: No price data found, symbol may be delisted (period=7d)
# ALGN: No price data found, symbol may be delisted (period=7d)
# RGDXQ: No price data found, symbol may be delisted (period=7d)
# Validation progress:   1%|▍                                                          | 43/5185 [00:03<05:37, 15.23it/s]DFIN: No price data found, symbol may be delisted (period=7d)
# MDXG: No price data found, symbol may be delisted (period=7d)
# JNJ: No price data found, symbol may be delisted (period=7d)
# Validation progress:   1%|▌                                                          | 46/5185 [00:03<06:30, 13.17it/s]REZI: No price data found, symbol may be delisted (period=7d)
# ALLGF: No price data found, symbol may be delisted (period=7d)
# TTNP: No price data found, symbol may be delisted (period=7d)
# TIOG: No price data found, symbol may be delisted (period=7d)
# TEM: No price data found, symbol may be delisted (period=7d)
# ALLK: No price data found, symbol may be delisted (period=7d)
# AZI: No price data found, symbol may be delisted (period=7d)
# SISI: No price data found, symbol may be delisted (period=7d)
# SUP: No price data found, symbol may be delisted (period=7d)                         | 53/5185 [00:04<05:42, 14.97it/s]
# Failed to get ticker 'CRD.B' reason: Expecting value: line 1 column 1 (char 0)
# FFIC: No price data found, symbol may be delisted (period=7d)
# CPA: No price data found, symbol may be delisted (period=7d)
# CPHI: No price data found, symbol may be delisted (period=7d)
# KOD: No price data found, symbol may be delisted (period=7d)
# Validation progress:   1%|▋                                                          | 58/5185 [00:04<05:47, 14.76it/s]NCMI: No price data found, symbol may be delisted (period=7d)
# MTRN: No price data found, symbol may be delisted (period=7d)
# FLYW: No price data found, symbol may be delisted (period=7d)
# CRD.B: No price data found, symbol may be delisted (period=7d)                       | 62/5185 [00:05<06:08, 13.89it/s]
# MEIP: No price data found, symbol may be delisted (period=7d)
# OFG: No price data found, symbol may be delisted (period=7d)
# BFST: No price data found, symbol may be delisted (period=7d)
# AMBC: No price data found, symbol may be delisted (period=7d)
# BPMC: No price data found, symbol may be delisted (period=7d)
# GOLF: No price data found, symbol may be delisted (period=7d)
# CHEF: No price data found, symbol may be delisted (period=7d)                        | 68/5185 [00:05<05:51, 14.55it/s]
# LMT: No price data found, symbol may be delisted (period=7d)
# MDT: No price data found, symbol may be delisted (period=7d)
# PFGC: No price data found, symbol may be delisted (period=7d)
# GURE: No price data found, symbol may be delisted (period=7d)
# INSE: No price data found, symbol may be delisted (period=7d)
# OCC: No price data found, symbol may be delisted (period=7d)
# QTWO: No price data found, symbol may be delisted (period=7d)                        | 75/5185 [00:05<05:22, 15.86it/s]
# SSBI: No price data found, symbol may be delisted (period=7d)
# CYCC: No price data found, symbol may be delisted (period=7d)
# AFMD: No price data found, symbol may be delisted (period=7d)
# PTC: No price data found, symbol may be delisted (period=7d)
# PMDI: No price data found, symbol may be delisted (period=7d)
# MSBI: No price data found, symbol may be delisted (period=7d)
# UTRS: No price data found, symbol may be delisted (period=7d)                        | 83/5185 [00:06<04:51, 17.48it/s]
# VANI: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'SFD' reason: Expecting value: line 1 column 1 (char 0)
# YSXT: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'CNR' reason: Expecting value: line 1 column 1 (char 0)
# NVTS: No price data found, symbol may be delisted (period=7d)
# TXN: No price data found, symbol may be delisted (period=7d)                         | 87/5185 [00:06<05:31, 15.36it/s]
# MCW: No price data found, symbol may be delisted (period=7d)
# MBLY: No price data found, symbol may be delisted (period=7d)
# VQSSF: No price data found, symbol may be delisted (period=7d)
# SFD: No price data found, symbol may be delisted (period=7d)
# SVVC: No price data found, symbol may be delisted (period=7d)
# FCBC: No price data found, symbol may be delisted (period=7d)                        | 92/5185 [00:06<05:54, 14.37it/s]
# CNR: No price data found, symbol may be delisted (period=7d)
# XFOR: No price data found, symbol may be delisted (period=7d)
# LFUS: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'CUTRQ' reason: Expecting value: line 1 column 1 (char 0)       | 97/5185 [00:07<05:51, 14.46it/s]
# CLBR: No price data found, symbol may be delisted (period=7d)
# ALMS: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'DXST' reason: Expecting value: line 1 column 1 (char 0)
# RM: No price data found, symbol may be delisted (period=7d)
# NRIX: No price data found, symbol may be delisted (period=7d)                       | 100/5185 [00:07<07:30, 11.29it/s]
# CUTRQ: No price data found, symbol may be delisted (period=7d)
# PAGS: No price data found, symbol may be delisted (period=7d)
# ONEW: No price data found, symbol may be delisted (period=7d)
# BTCY: No price data found, symbol may be delisted (period=7d)
# VLTO: No price data found, symbol may be delisted (period=7d)
# DD: No price data found, symbol may be delisted (period=7d)
# PAX: No price data found, symbol may be delisted (period=7d)
# DXST: No price data found, symbol may be delisted (period=7d)
# TLSI: No price data found, symbol may be delisted (period=7d)                       | 109/5185 [00:08<05:44, 14.75it/s]
# MEGEF: No price data found, symbol may be delisted (period=7d)
# VTEX: No price data found, symbol may be delisted (period=7d)
# RGLD: No price data found, symbol may be delisted (period=7d)
# Validation progress:   2%|█▎                                                        | 113/5185 [00:08<06:10, 13.69it/s]CLPT: No price data found, symbol may be delisted (period=7d)
# COCP: No price data found, symbol may be delisted (period=7d)
# GPLDF: No price data found, symbol may be delisted (period=7d)
# ACTU: No price data found, symbol may be delisted (period=7d)
# WFCF: No price data found, symbol may be delisted (period=7d)
# BPOP: No price data found, symbol may be delisted (period=7d)
# IE: No price data found, symbol may be delisted (period=7d)                         | 119/5185 [00:08<05:53, 14.35it/s]
# JMSB: No price data found, symbol may be delisted (period=7d)
# VFC: No price data found, symbol may be delisted (period=7d)
# WFRD: No price data found, symbol may be delisted (period=7d)
# IPSC: No price data found, symbol may be delisted (period=7d)
# BLFS: No price data found, symbol may be delisted (period=7d)
# PLTR: No price data found, symbol may be delisted (period=7d)
# OGN: No price data found, symbol may be delisted (period=7d)
# SPHL: No price data found, symbol may be delisted (period=7d)
# Validation progress:   2%|█▍                                                        | 127/5185 [00:09<05:12, 16.17it/s]Failed to get ticker 'CUPR' reason: Expecting value: line 1 column 1 (char 0)
# GNE: No price data found, symbol may be delisted (period=7d)
# NATL: No price data found, symbol may be delisted (period=7d)
# LWLG: No price data found, symbol may be delisted (period=7d)                       | 130/5185 [00:09<05:59, 14.06it/s]
# YHC: No price data found, symbol may be delisted (period=7d)
# EL: No price data found, symbol may be delisted (period=7d)
# PCG: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'BH.A' reason: Expecting value: line 1 column 1 (char 0)
# LTRY: No price data found, symbol may be delisted (period=7d)
# STAI: No price data found, symbol may be delisted (period=7d)
# VENU: No price data found, symbol may be delisted (period=7d)                       | 135/5185 [00:10<06:04, 13.87it/s]
# CUPR: No price data found, symbol may be delisted (period=7d)
# CNTM: No price data found, symbol may be delisted (period=7d)
# IP: No price data found, symbol may be delisted (period=7d)
# BH.A: No price data found, symbol may be delisted (period=7d)                       | 140/5185 [00:10<06:06, 13.77it/s]
# IGTA: No price data found, symbol may be delisted (period=7d)
# BRY: No price data found, symbol may be delisted (period=7d)
# TBMC: No price data found, symbol may be delisted (period=7d)
# TSN: No price data found, symbol may be delisted (period=7d)
# NOW: No price data found, symbol may be delisted (period=7d)                        | 145/5185 [00:10<06:03, 13.85it/s]
# TUEMQ: No price data found, symbol may be delisted (period=7d)
# GWRS: No price data found, symbol may be delisted (period=7d)
# BEEP: No price data found, symbol may be delisted (period=7d)
# SGRY: No price data found, symbol may be delisted (period=7d)
# SPTN: No price data found, symbol may be delisted (period=7d)
# AIP: No price data found, symbol may be delisted (period=7d)                        | 151/5185 [00:11<05:43, 14.67it/s]
# WSBC: No price data found, symbol may be delisted (period=7d)
# PINC: No price data found, symbol may be delisted (period=7d)
# CSL: No price data found, symbol may be delisted (period=7d)
# NWSA: No price data found, symbol may be delisted (period=7d)
# GTN: No price data found, symbol may be delisted (period=7d)
# Validation progress:   3%|█▋                                                        | 156/5185 [00:11<05:52, 14.26it/s]SXTP: No price data found, symbol may be delisted (period=7d)
# KRUS: No price data found, symbol may be delisted (period=7d)
# RBBN: No price data found, symbol may be delisted (period=7d)
# MGAM: No price data found, symbol may be delisted (period=7d)
# THRY: No price data found, symbol may be delisted (period=7d)
# OZK: No price data found, symbol may be delisted (period=7d)
# NOG: No price data found, symbol may be delisted (period=7d)
# ELMSQ: No price data found, symbol may be delisted (period=7d)                      | 164/5185 [00:11<04:51, 17.20it/s]
# FLGC: No price data found, symbol may be delisted (period=7d)
# PRVA: No price data found, symbol may be delisted (period=7d)                       | 166/5185 [00:12<06:12, 13.48it/s]
# Failed to get ticker 'DNMRQ' reason: Expecting value: line 1 column 1 (char 0)
# OTEX: No price data found, symbol may be delisted (period=7d)
# RIOT: No price data found, symbol may be delisted (period=7d)
# MMVVF: No price data found, symbol may be delisted (period=7d)
# ONCO: No price data found, symbol may be delisted (period=7d)
# ESTRF: No price data found, symbol may be delisted (period=7d)
# CPIX: No price data found, symbol may be delisted (period=7d)
# POAI: No price data found, symbol may be delisted (period=7d)
# AENT: No price data found, symbol may be delisted (period=7d)                       | 174/5185 [00:12<05:13, 15.96it/s]
# IZM: No price data found, symbol may be delisted (period=7d)
# DNMRQ: No price data found, symbol may be delisted (period=7d)
# TATT: No price data found, symbol may be delisted (period=7d)
# CRTD: No price data found, symbol may be delisted (period=7d)
# PRCH: No price data found, symbol may be delisted (period=7d)
# RAPP: No price data found, symbol may be delisted (period=7d)                       | 179/5185 [00:12<05:18, 15.73it/s]
# XRX: No price data found, symbol may be delisted (period=7d)
# SCM: No price data found, symbol may be delisted (period=7d)
# SOQDQ: No price data found, symbol may be delisted (period=7d)
# NCL: No price data found, symbol may be delisted (period=7d)
# FTCI: No price data found, symbol may be delisted (period=7d)                       | 184/5185 [00:13<05:38, 14.79it/s]
# KN: No price data found, symbol may be delisted (period=7d)
# WBA: No price data found, symbol may be delisted (period=7d)
# BODI: No price data found, symbol may be delisted (period=7d)
# ILAG: No price data found, symbol may be delisted (period=7d)
# MHUA: No price data found, symbol may be delisted (period=7d)
# HLX: No price data found, symbol may be delisted (period=7d)                        | 191/5185 [00:13<05:05, 16.33it/s]
# ESAB: No price data found, symbol may be delisted (period=7d)
# HAYW: No price data found, symbol may be delisted (period=7d)
# MMNFQ: No price data found, symbol may be delisted (period=7d)
# SLP: No price data found, symbol may be delisted (period=7d)                        | 194/5185 [00:13<05:54, 14.08it/s]
# BRSHF: No price data found, symbol may be delisted (period=7d)
# CCEP: No price data found, symbol may be delisted (period=7d)
# ASTI: No price data found, symbol may be delisted (period=7d)
# JOBY: No price data found, symbol may be delisted (period=7d)
# CRMT: No price data found, symbol may be delisted (period=7d)
# ULCC: No price data found, symbol may be delisted (period=7d)                       | 201/5185 [00:14<04:13, 19.67it/s]
# MOD: No price data found, symbol may be delisted (period=7d)
# VIAV: No price data found, symbol may be delisted (period=7d)
# TPST: No price data found, symbol may be delisted (period=7d)                       | 204/5185 [00:14<04:43, 17.58it/s]
# FSS: No price data found, symbol may be delisted (period=7d)
# LGVN: No price data found, symbol may be delisted (period=7d)
# DOCN: No price data found, symbol may be delisted (period=7d)
# LEGH: No price data found, symbol may be delisted (period=7d)
# Validation progress:   4%|██▎                                                       | 207/5185 [00:14<05:47, 14.32it/s]PLBC: No price data found, symbol may be delisted (period=7d)
# AWIN: No price data found, symbol may be delisted (period=7d)
# ZYME: No price data found, symbol may be delisted (period=7d)
# PARAA: No price data found, symbol may be delisted (period=7d)                      | 212/5185 [00:15<05:50, 14.19it/s]
# JOUT: No price data found, symbol may be delisted (period=7d)
# MOS: No price data found, symbol may be delisted (period=7d)
# QURE: No price data found, symbol may be delisted (period=7d)
# FYBR: No price data found, symbol may be delisted (period=7d)
# BAM: No price data found, symbol may be delisted (period=7d)
# PITA: No price data found, symbol may be delisted (period=7d)
# GSBD: No price data found, symbol may be delisted (period=7d)                       | 219/5185 [00:15<05:14, 15.78it/s]
# ENGN: No price data found, symbol may be delisted (period=7d)
# AER: No price data found, symbol may be delisted (period=7d)
# LIPO: No price data found, symbol may be delisted (period=7d)
# DTI: No price data found, symbol may be delisted (period=7d)
# MSS: No price data found, symbol may be delisted (period=7d)                        | 223/5185 [00:15<05:41, 14.55it/s]
# ANGO: No price data found, symbol may be delisted (period=7d)
# LNTH: No price data found, symbol may be delisted (period=7d)
# CAMP: No price data found, symbol may be delisted (period=7d)
# MVBF: No price data found, symbol may be delisted (period=7d)
# OPY: No price data found, symbol may be delisted (period=7d)
# NLSP: No price data found, symbol may be delisted (period=7d)
# PRI: No price data found, symbol may be delisted (period=7d)                        | 229/5185 [00:16<05:18, 15.58it/s]
# DNLI: No price data found, symbol may be delisted (period=7d)
# Validation progress:   4%|██▌                                                       | 233/5185 [00:16<05:53, 14.00it/s]LUCY: No price data found, symbol may be delisted (period=7d)
# NEUE: No price data found, symbol may be delisted (period=7d)
# LSTR: No price data found, symbol may be delisted (period=7d)
# DSGX: No price data found, symbol may be delisted (period=7d)
# HOPE: No price data found, symbol may be delisted (period=7d)
# ANEB: No price data found, symbol may be delisted (period=7d)
# EOLS: No price data found, symbol may be delisted (period=7d)
# QGEN: No price data found, symbol may be delisted (period=7d)
# GMBL: No price data found, symbol may be delisted (period=7d)                       | 241/5185 [00:16<05:01, 16.42it/s]
# PRPL: No price data found, symbol may be delisted (period=7d)
# FITB: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'TETEF' reason: Expecting value: line 1 column 1 (char 0)
# MAMA: No price data found, symbol may be delisted (period=7d)
# PEN: No price data found, symbol may be delisted (period=7d)                        | 245/5185 [00:17<05:30, 14.93it/s]
# Failed to get ticker 'XYZ' reason: Expecting value: line 1 column 1 (char 0)
# EMCG: No price data found, symbol may be delisted (period=7d)
# PRTS: No price data found, symbol may be delisted (period=7d)
# GPRE: No price data found, symbol may be delisted (period=7d)
# AMR: No price data found, symbol may be delisted (period=7d)
# ELDN: No price data found, symbol may be delisted (period=7d)                       | 250/5185 [00:17<05:45, 14.29it/s]
# TETEF: No price data found, symbol may be delisted (period=7d)
# FOA: No price data found, symbol may be delisted (period=7d)
# TPH: No price data found, symbol may be delisted (period=7d)
# XYZ: No price data found, symbol may be delisted (period=7d)
# ADPT: No price data found, symbol may be delisted (period=7d)
# STLA: No price data found, symbol may be delisted (period=7d)
# BV: No price data found, symbol may be delisted (period=7d)
# THM: No price data found, symbol may be delisted (period=7d)
# YUM: No price data found, symbol may be delisted (period=7d)                        | 259/5185 [00:17<04:45, 17.23it/s]
# MDAI: No price data found, symbol may be delisted (period=7d)
# GP: No price data found, symbol may be delisted (period=7d)
# UP: No price data found, symbol may be delisted (period=7d)
# CCIR: No price data found, symbol may be delisted (period=7d)
# Validation progress:   5%|██▉                                                       | 264/5185 [00:18<04:54, 16.70it/s]BRO: No price data found, symbol may be delisted (period=7d)
# AGI: No price data found, symbol may be delisted (period=7d)
# AROW: No price data found, symbol may be delisted (period=7d)
# RLAY: No price data found, symbol may be delisted (period=7d)
# BTOC: No price data found, symbol may be delisted (period=7d)
# TBPH: No price data found, symbol may be delisted (period=7d)
# Validation progress:   5%|███                                                       | 269/5185 [00:18<05:11, 15.78it/s]HSCS: No price data found, symbol may be delisted (period=7d)
# ZETA: No price data found, symbol may be delisted (period=7d)
# TNC: No price data found, symbol may be delisted (period=7d)
# VKTX: No price data found, symbol may be delisted (period=7d)
# TNEN: No price data found, symbol may be delisted (period=7d)
# LSDIF: No price data found, symbol may be delisted (period=7d)                      | 275/5185 [00:19<05:12, 15.69it/s]
# PAYX: No price data found, symbol may be delisted (period=7d)
# YRIV: No price data found, symbol may be delisted (period=7d)
# FND: No price data found, symbol may be delisted (period=7d)
# COOP: No price data found, symbol may be delisted (period=7d)
# PFS: No price data found, symbol may be delisted (period=7d)                        | 279/5185 [00:19<05:40, 14.39it/s]
# CODA: No price data found, symbol may be delisted (period=7d)
# ALTI: No price data found, symbol may be delisted (period=7d)
# RAPT: No price data found, symbol may be delisted (period=7d)
# CBSH: No price data found, symbol may be delisted (period=7d)
# RYI: No price data found, symbol may be delisted (period=7d)
# Validation progress:   6%|███▏                                                      | 286/5185 [00:19<05:14, 15.59it/s]ASLE: No price data found, symbol may be delisted (period=7d)
# CARR: No price data found, symbol may be delisted (period=7d)
# PAPL: No price data found, symbol may be delisted (period=7d)
# VLN: No price data found, symbol may be delisted (period=7d)
# ABNB: No price data found, symbol may be delisted (period=7d)
# FBLG: No price data found, symbol may be delisted (period=7d)
# PSBD: No price data found, symbol may be delisted (period=7d)
# OCUL: No price data found, symbol may be delisted (period=7d)                       | 292/5185 [00:20<05:05, 16.04it/s]
# BRZE: No price data found, symbol may be delisted (period=7d)
# MANH: No price data found, symbol may be delisted (period=7d)
# BNRG: No price data found, symbol may be delisted (period=7d)                       | 296/5185 [00:20<05:40, 14.36it/s]
# BBGI: No price data found, symbol may be delisted (period=7d)
# UNCY: No price data found, symbol may be delisted (period=7d)
# MHK: No price data found, symbol may be delisted (period=7d)
# ATS: No price data found, symbol may be delisted (period=7d)
# SSBK: No price data found, symbol may be delisted (period=7d)
# EVBN: No price data found, symbol may be delisted (period=7d)
# ACNB: No price data found, symbol may be delisted (period=7d)
# ADT: No price data found, symbol may be delisted (period=7d)
# AONC: No price data found, symbol may be delisted (period=7d)                       | 304/5185 [00:20<04:57, 16.39it/s]
# WTS: No price data found, symbol may be delisted (period=7d)
# DHI: No price data found, symbol may be delisted (period=7d)
# INO: No price data found, symbol may be delisted (period=7d)
# TRSG: No price data found, symbol may be delisted (period=7d)
# PPSI: No price data found, symbol may be delisted (period=7d)                       | 310/5185 [00:21<04:50, 16.76it/s]
# HCAT: No price data found, symbol may be delisted (period=7d)
# AUBN: No price data found, symbol may be delisted (period=7d)
# LEE: No price data found, symbol may be delisted (period=7d)
# OPRT: No price data found, symbol may be delisted (period=7d)                       | 314/5185 [00:21<05:21, 15.14it/s]
# UTMD: No price data found, symbol may be delisted (period=7d)
# CCOI: No price data found, symbol may be delisted (period=7d)
# BKE: No price data found, symbol may be delisted (period=7d)
# RUSHB: No price data found, symbol may be delisted (period=7d)
# INTR: No price data found, symbol may be delisted (period=7d)
# RDIB: No price data found, symbol may be delisted (period=7d)
# AMCR: No price data found, symbol may be delisted (period=7d)
# FA: No price data found, symbol may be delisted (period=7d)
# FTHM: No price data found, symbol may be delisted (period=7d)                       | 323/5185 [00:21<04:32, 17.81it/s]
# JHG: No price data found, symbol may be delisted (period=7d)
# ATRA: No price data found, symbol may be delisted (period=7d)
# OTTV: No price data found, symbol may be delisted (period=7d)
# KALV: No price data found, symbol may be delisted (period=7d)                       | 327/5185 [00:22<05:08, 15.75it/s]
# Failed to get ticker 'CJMB' reason: Expecting value: line 1 column 1 (char 0)
# DGX: No price data found, symbol may be delisted (period=7d)
# XXII: No price data found, symbol may be delisted (period=7d)
# SVBL: No price data found, symbol may be delisted (period=7d)
# KSCP: No price data found, symbol may be delisted (period=7d)
# LKFN: No price data found, symbol may be delisted (period=7d)                       | 332/5185 [00:22<05:13, 15.50it/s]
# DOCU: No price data found, symbol may be delisted (period=7d)
# WGS: No price data found, symbol may be delisted (period=7d)
# STGW: No price data found, symbol may be delisted (period=7d)
# PLUG: No price data found, symbol may be delisted (period=7d)                       | 336/5185 [00:22<05:33, 14.53it/s]
# MBOT: No price data found, symbol may be delisted (period=7d)
# OCTO: No price data found, symbol may be delisted (period=7d)
# FHB: No price data found, symbol may be delisted (period=7d)
# CJMB: No price data found, symbol may be delisted (period=7d)
# BBXIA: No price data found, symbol may be delisted (period=7d)
# Validation progress:   7%|███▊                                                      | 342/5185 [00:23<05:18, 15.22it/s]WMG: No price data found, symbol may be delisted (period=7d)
# MGPI: No price data found, symbol may be delisted (period=7d)
# EOSE: No price data found, symbol may be delisted (period=7d)
# EBMT: No price data found, symbol may be delisted (period=7d)
# IMMX: No price data found, symbol may be delisted (period=7d)
# PLNT: No price data found, symbol may be delisted (period=7d)                       | 347/5185 [00:23<06:09, 13.08it/s]
# AFYA: No price data found, symbol may be delisted (period=7d)
# LINUF: No price data found, symbol may be delisted (period=7d)
# NWBI: No price data found, symbol may be delisted (period=7d)
# BANR: No price data found, symbol may be delisted (period=7d)
# SWSS: No price data found, symbol may be delisted (period=7d)                       | 352/5185 [00:24<05:58, 13.48it/s]
# HOOD: No price data found, symbol may be delisted (period=7d)
# MED: No price data found, symbol may be delisted (period=7d)
# PPC: No price data found, symbol may be delisted (period=7d)
# HPAI: No price data found, symbol may be delisted (period=7d)
# ZCMD: No price data found, symbol may be delisted (period=7d)
# SXC: No price data found, symbol may be delisted (period=7d)                        | 357/5185 [00:24<05:58, 13.46it/s]
# GASS: No price data found, symbol may be delisted (period=7d)
# LSAK: No price data found, symbol may be delisted (period=7d)
# BGC: No price data found, symbol may be delisted (period=7d)
# STTO: No price data found, symbol may be delisted (period=7d)
# VRME: No price data found, symbol may be delisted (period=7d)                       | 363/5185 [00:24<05:25, 14.79it/s]
# COP: No price data found, symbol may be delisted (period=7d)
# CYTOF: No price data found, symbol may be delisted (period=7d)
# HNRG: No price data found, symbol may be delisted (period=7d)
# IGC: No price data found, symbol may be delisted (period=7d)
# LMPX: No price data found, symbol may be delisted (period=7d)
# PHIN: No price data found, symbol may be delisted (period=7d)
# BBSI: No price data found, symbol may be delisted (period=7d)                       | 370/5185 [00:25<04:49, 16.61it/s]
# PR: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'CRD.A' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PN' reason: Expecting value: line 1 column 1 (char 0)
# COTY: No price data found, symbol may be delisted (period=7d)
# IR: No price data found, symbol may be delisted (period=7d)
# BLUAF: No price data found, symbol may be delisted (period=7d)                      | 373/5185 [00:25<05:42, 14.05it/s]
# ABOS: No price data found, symbol may be delisted (period=7d)
# BEAG: No price data found, symbol may be delisted (period=7d)
# DYN: No price data found, symbol may be delisted (period=7d)
# Validation progress:   7%|████▏                                                     | 378/5185 [00:25<05:40, 14.13it/s]SKYE: No price data found, symbol may be delisted (period=7d)
# THCH: No price data found, symbol may be delisted (period=7d)
# CRD.A: No price data found, symbol may be delisted (period=7d)
# PN: No price data found, symbol may be delisted (period=7d)
# WLDS: No price data found, symbol may be delisted (period=7d)                       | 381/5185 [00:26<06:28, 12.36it/s]
# XP: No price data found, symbol may be delisted (period=7d)
# VTLE: No price data found, symbol may be delisted (period=7d)
# NEU: No price data found, symbol may be delisted (period=7d)
# ALDF: No price data found, symbol may be delisted (period=7d)
# VYNE: No price data found, symbol may be delisted (period=7d)
# WEJOF: No price data found, symbol may be delisted (period=7d)
# YAAS: No price data found, symbol may be delisted (period=7d)                       | 388/5185 [00:26<05:32, 14.41it/s]
# AAME: No price data found, symbol may be delisted (period=7d)
# RGEN: No price data found, symbol may be delisted (period=7d)
# GORO: No price data found, symbol may be delisted (period=7d)
# CERS: No price data found, symbol may be delisted (period=7d)
# ITRN: No price data found, symbol may be delisted (period=7d)                       | 393/5185 [00:27<05:41, 14.02it/s]
# DMAC: No price data found, symbol may be delisted (period=7d)
# RAIL: No price data found, symbol may be delisted (period=7d)
# CFBK: No price data found, symbol may be delisted (period=7d)
# THTX: No price data found, symbol may be delisted (period=7d)
# CWK: No price data found, symbol may be delisted (period=7d)
# ORRF: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'ASBP' reason: Expecting value: line 1 column 1 (char 0)
# SLQT: No price data found, symbol may be delisted (period=7d)                       | 400/5185 [00:27<05:12, 15.31it/s]
# MCOM: No price data found, symbol may be delisted (period=7d)
# BTMD: No price data found, symbol may be delisted (period=7d)
# FVRR: No price data found, symbol may be delisted (period=7d)
# ULY: No price data found, symbol may be delisted (period=7d)
# RCL: No price data found, symbol may be delisted (period=7d)
# JELD: No price data found, symbol may be delisted (period=7d)                       | 406/5185 [00:27<05:12, 15.28it/s]
# BCG: No price data found, symbol may be delisted (period=7d)
# ASBP: No price data found, symbol may be delisted (period=7d)                       | 409/5185 [00:28<05:54, 13.48it/s]
# CAPR: No price data found, symbol may be delisted (period=7d)
# ALT: No price data found, symbol may be delisted (period=7d)
# BTG: No price data found, symbol may be delisted (period=7d)
# PCOR: No price data found, symbol may be delisted (period=7d)
# OPOF: No price data found, symbol may be delisted (period=7d)
# PYXS: No price data found, symbol may be delisted (period=7d)
# SERA: No price data found, symbol may be delisted (period=7d)                       | 416/5185 [00:28<05:15, 15.10it/s]
# Failed to get ticker 'MKC.V' reason: Expecting value: line 1 column 1 (char 0)
# MGHL: No price data found, symbol may be delisted (period=7d)
# SPEC: No price data found, symbol may be delisted (period=7d)
# Validation progress:   8%|████▋                                                     | 419/5185 [00:28<06:06, 13.01it/s]COST: No price data found, symbol may be delisted (period=7d)
# FUL: No price data found, symbol may be delisted (period=7d)
# OPTN: No price data found, symbol may be delisted (period=7d)
# PC: No price data found, symbol may be delisted (period=7d)
# DGLY: No price data found, symbol may be delisted (period=7d)
# SSUNF: No price data found, symbol may be delisted (period=7d)
# SMMT: No price data found, symbol may be delisted (period=7d)
# Validation progress:   8%|████▊                                                     | 425/5185 [00:29<05:37, 14.10it/s]CRL: No price data found, symbol may be delisted (period=7d)
# MKC.V: No price data found, symbol may be delisted (period=7d)
# HOG: No price data found, symbol may be delisted (period=7d)
# ORGS: No price data found, symbol may be delisted (period=7d)
# ASST: No price data found, symbol may be delisted (period=7d)                       | 429/5185 [00:29<05:56, 13.34it/s]
# LIEN: No price data found, symbol may be delisted (period=7d)
# BCBP: No price data found, symbol may be delisted (period=7d)
# MTH: No price data found, symbol may be delisted (period=7d)
# PWM: No price data found, symbol may be delisted (period=7d)
# DE: No price data found, symbol may be delisted (period=7d)                         | 435/5185 [00:29<05:28, 14.45it/s]
# ROMA: No price data found, symbol may be delisted (period=7d)
# TNL: No price data found, symbol may be delisted (period=7d)
# VMD: No price data found, symbol may be delisted (period=7d)
# META: No price data found, symbol may be delisted (period=7d)                       | 439/5185 [00:30<05:46, 13.68it/s]
# CP: No price data found, symbol may be delisted (period=7d)
# LZ: No price data found, symbol may be delisted (period=7d)
# FOXO: No price data found, symbol may be delisted (period=7d)
# WATT: No price data found, symbol may be delisted (period=7d)
# GFR: No price data found, symbol may be delisted (period=7d)
# Validation progress:   9%|████▉                                                     | 445/5185 [00:30<05:26, 14.51it/s]FWRG: No price data found, symbol may be delisted (period=7d)
# STLD: No price data found, symbol may be delisted (period=7d)
# ARQQ: No price data found, symbol may be delisted (period=7d)
# LOCM: No price data found, symbol may be delisted (period=7d)
# LOB: No price data found, symbol may be delisted (period=7d)
# GRC: No price data found, symbol may be delisted (period=7d)
# ELA: No price data found, symbol may be delisted (period=7d)
# ICCT: No price data found, symbol may be delisted (period=7d)                       | 452/5185 [00:31<05:00, 15.74it/s]
# Failed to get ticker 'MAYA' reason: Expecting value: line 1 column 1 (char 0)
# BRLT: No price data found, symbol may be delisted (period=7d)
# Validation progress:   9%|█████                                                     | 454/5185 [00:31<06:05, 12.95it/s]SWAG: No price data found, symbol may be delisted (period=7d)
# CUEN: No price data found, symbol may be delisted (period=7d)
# SYRS: No price data found, symbol may be delisted (period=7d)
# PRLD: No price data found, symbol may be delisted (period=7d)
# ASPI: No price data found, symbol may be delisted (period=7d)
# PUCK: No price data found, symbol may be delisted (period=7d)
# PRDO: No price data found, symbol may be delisted (period=7d)
# TTMI: No price data found, symbol may be delisted (period=7d)                       | 461/5185 [00:31<05:17, 14.90it/s]
# SENS: No price data found, symbol may be delisted (period=7d)
# NAOV: No price data found, symbol may be delisted (period=7d)
# MAYA: No price data found, symbol may be delisted (period=7d)
# SLHGF: No price data found, symbol may be delisted (period=7d)
# ALGT: No price data found, symbol may be delisted (period=7d)
# MSAI: No price data found, symbol may be delisted (period=7d)                       | 466/5185 [00:32<05:33, 14.14it/s]
# MDRX: No price data found, symbol may be delisted (period=7d)
# GALT: No price data found, symbol may be delisted (period=7d)
# SMP: No price data found, symbol may be delisted (period=7d)
# BMRN: No price data found, symbol may be delisted (period=7d)                       | 471/5185 [00:32<05:37, 13.97it/s]
# CLMB: No price data found, symbol may be delisted (period=7d)
# KLC: No price data found, symbol may be delisted (period=7d)
# SCNX: No price data found, symbol may be delisted (period=7d)
# ELAB: No price data found, symbol may be delisted (period=7d)
# EVCM: No price data found, symbol may be delisted (period=7d)
# LEXX: No price data found, symbol may be delisted (period=7d)                       | 476/5185 [00:32<05:44, 13.69it/s]
# RENO: No price data found, symbol may be delisted (period=7d)
# SCPH: No price data found, symbol may be delisted (period=7d)
# FDX: No price data found, symbol may be delisted (period=7d)
# ACVA: No price data found, symbol may be delisted (period=7d)
# GTBP: No price data found, symbol may be delisted (period=7d)                       | 482/5185 [00:33<05:12, 15.07it/s]
# BC: No price data found, symbol may be delisted (period=7d)
# EJH: No price data found, symbol may be delisted (period=7d)
# SNOA: No price data found, symbol may be delisted (period=7d)
# FINW: No price data found, symbol may be delisted (period=7d)                       | 486/5185 [00:33<05:37, 13.90it/s]
# HSII: No price data found, symbol may be delisted (period=7d)
# FNLC: No price data found, symbol may be delisted (period=7d)
# AVA: No price data found, symbol may be delisted (period=7d)
# REE: No price data found, symbol may be delisted (period=7d)
# SIGA: No price data found, symbol may be delisted (period=7d)
# FBK: No price data found, symbol may be delisted (period=7d)                        | 492/5185 [00:33<05:22, 14.57it/s]
# FLUX: No price data found, symbol may be delisted (period=7d)
# REX: No price data found, symbol may be delisted (period=7d)
# BEEM: No price data found, symbol may be delisted (period=7d)
# HALO: No price data found, symbol may be delisted (period=7d)                       | 496/5185 [00:34<05:44, 13.59it/s]
# AL: No price data found, symbol may be delisted (period=7d)
# WBD: No price data found, symbol may be delisted (period=7d)
# CRDO: No price data found, symbol may be delisted (period=7d)
# PETZ: No price data found, symbol may be delisted (period=7d)
# DPZ: No price data found, symbol may be delisted (period=7d)
# BAOS: No price data found, symbol may be delisted (period=7d)
# HFFG: No price data found, symbol may be delisted (period=7d)                       | 502/5185 [00:34<05:18, 14.71it/s]
# ATNI: No price data found, symbol may be delisted (period=7d)
# CDVIQ: No price data found, symbol may be delisted (period=7d)
# SNFCA: No price data found, symbol may be delisted (period=7d)                      | 506/5185 [00:34<05:40, 13.73it/s]
# GNLX: No price data found, symbol may be delisted (period=7d)
# AZTA: No price data found, symbol may be delisted (period=7d)
# ENVB: No price data found, symbol may be delisted (period=7d)
# GDEV: No price data found, symbol may be delisted (period=7d)
# AFIIQ: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'LUD' reason: Expecting value: line 1 column 1 (char 0)
# LARK: No price data found, symbol may be delisted (period=7d)                       | 512/5185 [00:35<05:21, 14.55it/s]
# CDRE: No price data found, symbol may be delisted (period=7d)
# NOTV: No price data found, symbol may be delisted (period=7d)
# UOKA: No price data found, symbol may be delisted (period=7d)
# BITCF: No price data found, symbol may be delisted (period=7d)                      | 516/5185 [00:35<05:37, 13.83it/s]
# PEGA: No price data found, symbol may be delisted (period=7d)
# CELU: No price data found, symbol may be delisted (period=7d)
# BRKL: No price data found, symbol may be delisted (period=7d)
# ZION: No price data found, symbol may be delisted (period=7d)
# CNET: No price data found, symbol may be delisted (period=7d)                       | 521/5185 [00:36<05:31, 14.07it/s]
# PAY: No price data found, symbol may be delisted (period=7d)
# GXO: No price data found, symbol may be delisted (period=7d)
# LUD: No price data found, symbol may be delisted (period=7d)
# ATI: No price data found, symbol may be delisted (period=7d)
# CBNA: No price data found, symbol may be delisted (period=7d)                       | 526/5185 [00:36<05:37, 13.80it/s]
# TRVI: No price data found, symbol may be delisted (period=7d)
# COO: No price data found, symbol may be delisted (period=7d)
# EGLXF: No price data found, symbol may be delisted (period=7d)
# PRAA: No price data found, symbol may be delisted (period=7d)
# DCGO: No price data found, symbol may be delisted (period=7d)
# CMBT: No price data found, symbol may be delisted (period=7d)                       | 532/5185 [00:36<05:13, 14.85it/s]
# CRNT: No price data found, symbol may be delisted (period=7d)
# STX: No price data found, symbol may be delisted (period=7d)
# IPI: No price data found, symbol may be delisted (period=7d)
# BH: No price data found, symbol may be delisted (period=7d)                         | 536/5185 [00:37<05:36, 13.80it/s]
# TEN: No price data found, symbol may be delisted (period=7d)
# KAPA: No price data found, symbol may be delisted (period=7d)
# PHAT: No price data found, symbol may be delisted (period=7d)
# WERN: No price data found, symbol may be delisted (period=7d)
# CZNC: No price data found, symbol may be delisted (period=7d)
# EDMCQ: No price data found, symbol may be delisted (period=7d)
# MATW: No price data found, symbol may be delisted (period=7d)                       | 543/5185 [00:37<04:56, 15.66it/s]
# Failed to get ticker 'ZOMDF' reason: Expecting value: line 1 column 1 (char 0)
# ARCO: No price data found, symbol may be delisted (period=7d)
# SITE: No price data found, symbol may be delisted (period=7d)                       | 545/5185 [00:37<06:17, 12.29it/s]
# OGE: No price data found, symbol may be delisted (period=7d)
# MRUS: No price data found, symbol may be delisted (period=7d)
# WSO: No price data found, symbol may be delisted (period=7d)
# GENC: No price data found, symbol may be delisted (period=7d)
# HEI: No price data found, symbol may be delisted (period=7d)
# LNKB: No price data found, symbol may be delisted (period=7d)
# ATER: No price data found, symbol may be delisted (period=7d)                       | 552/5185 [00:38<05:21, 14.40it/s]
# ZOMDF: No price data found, symbol may be delisted (period=7d)
# SKIL: No price data found, symbol may be delisted (period=7d)
# WAT: No price data found, symbol may be delisted (period=7d)
# Validation progress:  11%|██████▏                                                   | 556/5185 [00:38<05:38, 13.68it/s]OPXS: No price data found, symbol may be delisted (period=7d)
# UTSI: No price data found, symbol may be delisted (period=7d)
# ONFO: No price data found, symbol may be delisted (period=7d)
# LFST: No price data found, symbol may be delisted (period=7d)
# CCRD: No price data found, symbol may be delisted (period=7d)
# BWFG: No price data found, symbol may be delisted (period=7d)
# MSW: No price data found, symbol may be delisted (period=7d)                        | 562/5185 [00:38<05:19, 14.48it/s]
# ZBH: No price data found, symbol may be delisted (period=7d)
# RICK: No price data found, symbol may be delisted (period=7d)
# PCB: No price data found, symbol may be delisted (period=7d)
# LTBR: No price data found, symbol may be delisted (period=7d)
# TPVG: No price data found, symbol may be delisted (period=7d)
# OLB: No price data found, symbol may be delisted (period=7d)                        | 568/5185 [00:39<05:05, 15.11it/s]
# LC: No price data found, symbol may be delisted (period=7d)
# LSB: No price data found, symbol may be delisted (period=7d)
# DNUT: No price data found, symbol may be delisted (period=7d)
# Validation progress:  11%|██████▍                                                   | 572/5185 [00:39<05:37, 13.66it/s]Z: No price data found, symbol may be delisted (period=7d)
# WELNF: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'XAGE' reason: Expecting value: line 1 column 1 (char 0)
# LYRA: No price data found, symbol may be delisted (period=7d)
# ICE: No price data found, symbol may be delisted (period=7d)
# HRL: No price data found, symbol may be delisted (period=7d)
# PBPB: No price data found, symbol may be delisted (period=7d)
# MGHCF: No price data found, symbol may be delisted (period=7d)                      | 578/5185 [00:39<05:09, 14.88it/s]
# BBW: No price data found, symbol may be delisted (period=7d)
# NXST: No price data found, symbol may be delisted (period=7d)
# GCBC: No price data found, symbol may be delisted (period=7d)
# COMS: No price data found, symbol may be delisted (period=7d)
# ZPAS: No price data found, symbol may be delisted (period=7d)                       | 582/5185 [00:40<05:50, 13.13it/s]
# IDXG: No price data found, symbol may be delisted (period=7d)
# SPGI: No price data found, symbol may be delisted (period=7d)
# XAGE: No price data found, symbol may be delisted (period=7d)
# WTTR: No price data found, symbol may be delisted (period=7d)
# VRN: No price data found, symbol may be delisted (period=7d)
# LGL: No price data found, symbol may be delisted (period=7d)
# TANH: No price data found, symbol may be delisted (period=7d)                       | 590/5185 [00:40<05:07, 14.95it/s]
# COFS: No price data found, symbol may be delisted (period=7d)
# KTTA: No price data found, symbol may be delisted (period=7d)
# XERS: No price data found, symbol may be delisted (period=7d)
# TSLA: No price data found, symbol may be delisted (period=7d)
# TYGO: No price data found, symbol may be delisted (period=7d)                       | 595/5185 [00:41<05:11, 14.74it/s]
# ARIS: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'HMR' reason: Expecting value: line 1 column 1 (char 0)
# RLGT: No price data found, symbol may be delisted (period=7d)
# GSM: No price data found, symbol may be delisted (period=7d)
# FBIZ: No price data found, symbol may be delisted (period=7d)                       | 599/5185 [00:41<05:33, 13.75it/s]
# CTSH: No price data found, symbol may be delisted (period=7d)
# ALSAF: No price data found, symbol may be delisted (period=7d)
# CARV: No price data found, symbol may be delisted (period=7d)
# EWTX: No price data found, symbol may be delisted (period=7d)
# SCHW: No price data found, symbol may be delisted (period=7d)                       | 604/5185 [00:41<05:35, 13.66it/s]
# HHH: No price data found, symbol may be delisted (period=7d)
# TRGP: No price data found, symbol may be delisted (period=7d)
# AXGN: No price data found, symbol may be delisted (period=7d)
# HMR: No price data found, symbol may be delisted (period=7d)
# NTIOF: No price data found, symbol may be delisted (period=7d)
# CNA: No price data found, symbol may be delisted (period=7d)                        | 610/5185 [00:42<05:18, 14.36it/s]
# SPFI: No price data found, symbol may be delisted (period=7d)
# TBIO: No price data found, symbol may be delisted (period=7d)
# SMXT: No price data found, symbol may be delisted (period=7d)
# ...
# ORMP: No price data found, symbol may be delisted (period=7d)
# TUSK: No price data found, symbol may be delisted (period=7d)███████████████████▊  | 4986/5185 [05:06<00:15, 13.03it/s]
# ZIMV: No price data found, symbol may be delisted (period=7d)
# GMS: No price data found, symbol may be delisted (period=7d)
# ANSS: No price data found, symbol may be delisted (period=7d)
# IBTA: No price data found, symbol may be delisted (period=7d)
# BSGM: No price data found, symbol may be delisted (period=7d)
# ICON: No price data found, symbol may be delisted (period=7d)
# TRNS: No price data found, symbol may be delisted (period=7d)
# SHCO: No price data found, symbol may be delisted (period=7d)███████████████████▉  | 4994/5185 [05:06<00:11, 16.16it/s]
# MNPR: No price data found, symbol may be delisted (period=7d)
# CNK: No price data found, symbol may be delisted (period=7d)
# AXXDF: No price data found, symbol may be delisted (period=7d)
# ABL: No price data found, symbol may be delisted (period=7d)████████████████████▉  | 4997/5185 [05:07<00:14, 13.38it/s]
# OPAL: No price data found, symbol may be delisted (period=7d)
# HFBL: No price data found, symbol may be delisted (period=7d)
# ACFN: No price data found, symbol may be delisted (period=7d)
# STKS: No price data found, symbol may be delisted (period=7d)
# ARW: No price data found, symbol may be delisted (period=7d)
# CPSH: No price data found, symbol may be delisted (period=7d)
# DFS: No price data found, symbol may be delisted (period=7d)█████████████████████  | 5005/5185 [05:07<00:11, 16.23it/s]
# FULC: No price data found, symbol may be delisted (period=7d)
# Validation progress:  97%|███████████████████████████████████████████████████████  | 5007/5185 [05:08<00:13, 12.77it/s]DSAQ: No price data found, symbol may be delisted (period=7d)
# FTDR: No price data found, symbol may be delisted (period=7d)
# BHF: No price data found, symbol may be delisted (period=7d)
# PRGO: No price data found, symbol may be delisted (period=7d)
# GCI: No price data found, symbol may be delisted (period=7d)
# GITS: No price data found, symbol may be delisted (period=7d)
# ARBE: No price data found, symbol may be delisted (period=7d)
# DRRX: No price data found, symbol may be delisted (period=7d)
# PG: No price data found, symbol may be delisted (period=7d)
# Validation progress:  97%|███████████████████████████████████████████████████████▏ | 5016/5185 [05:08<00:10, 16.29it/s]HSHP: No price data found, symbol may be delisted (period=7d)
# CHPT: No price data found, symbol may be delisted (period=7d)
# PAYO: No price data found, symbol may be delisted (period=7d)
# CAVA: No price data found, symbol may be delisted (period=7d)████████████████████▏ | 5019/5185 [05:08<00:11, 13.95it/s]
# PSTG: No price data found, symbol may be delisted (period=7d)
# LPTX: No price data found, symbol may be delisted (period=7d)
# PDEX: No price data found, symbol may be delisted (period=7d)
# ALYAF: No price data found, symbol may be delisted (period=7d)
# NC: No price data found, symbol may be delisted (period=7d)
# DY: No price data found, symbol may be delisted (period=7d)
# GLE: No price data found, symbol may be delisted (period=7d)█████████████████████▎ | 5026/5185 [05:09<00:10, 15.56it/s]
# KRRO: No price data found, symbol may be delisted (period=7d)
# RDNT: No price data found, symbol may be delisted (period=7d)
# CREX: No price data found, symbol may be delisted (period=7d)
# YTRA: No price data found, symbol may be delisted (period=7d)████████████████████▎ | 5030/5185 [05:09<00:11, 13.81it/s]
# STI: No price data found, symbol may be delisted (period=7d)
# DTST: No price data found, symbol may be delisted (period=7d)
# LTRPA: No price data found, symbol may be delisted (period=7d)
# PFX: No price data found, symbol may be delisted (period=7d)
# GROY: No price data found, symbol may be delisted (period=7d)
# YYAI: No price data found, symbol may be delisted (period=7d)████████████████████▎ | 5036/5185 [05:09<00:08, 18.19it/s]
# IIIV: No price data found, symbol may be delisted (period=7d)
# VRNS: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'ALMU' reason: Expecting value: line 1 column 1 (char 0)
# GRAL: No price data found, symbol may be delisted (period=7d)████████████████████▍ | 5039/5185 [05:09<00:09, 16.21it/s]
# ALGS: No price data found, symbol may be delisted (period=7d)
# ACIU: No price data found, symbol may be delisted (period=7d)
# DSUS: No price data found, symbol may be delisted (period=7d)████████████████████▍ | 5042/5185 [05:10<00:10, 13.26it/s]
# KOS: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'CYCU' reason: Expecting value: line 1 column 1 (char 0)
# LW: No price data found, symbol may be delisted (period=7d)
# AMED: No price data found, symbol may be delisted (period=7d)
# TRC: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'EHLD' reason: Expecting value: line 1 column 1 (char 0)████▍ | 5046/5185 [05:10<00:11, 12.56it/s]
# FBYD: No price data found, symbol may be delisted (period=7d)
# ALMU: No price data found, symbol may be delisted (period=7d)
# RAIN: No price data found, symbol may be delisted (period=7d)
# CYCU: No price data found, symbol may be delisted (period=7d)
# DUO: No price data found, symbol may be delisted (period=7d)█████████████████████▌ | 5051/5185 [05:10<00:10, 13.04it/s]
# GLUE: No price data found, symbol may be delisted (period=7d)
# EHLD: No price data found, symbol may be delisted (period=7d)
# QSI: No price data found, symbol may be delisted (period=7d)
# BNZI: No price data found, symbol may be delisted (period=7d)
# WFG: No price data found, symbol may be delisted (period=7d)
# BEBE: No price data found, symbol may be delisted (period=7d)
# CXW: No price data found, symbol may be delisted (period=7d)█████████████████████▌ | 5058/5185 [05:11<00:08, 15.29it/s]
# SAVA: No price data found, symbol may be delisted (period=7d)
# AWX: No price data found, symbol may be delisted (period=7d)
# Validation progress:  98%|███████████████████████████████████████████████████████▋ | 5061/5185 [05:11<00:09, 13.41it/s]RR: No price data found, symbol may be delisted (period=7d)
# FLWS: No price data found, symbol may be delisted (period=7d)
# RSG: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'BHILQ' reason: Expecting value: line 1 column 1 (char 0)
# FMST: No price data found, symbol may be delisted (period=7d)
# CHSN: No price data found, symbol may be delisted (period=7d)
# ALGM: No price data found, symbol may be delisted (period=7d)
# VHC: No price data found, symbol may be delisted (period=7d)
# MAGN: No price data found, symbol may be delisted (period=7d)████████████████████▋ | 5067/5185 [05:12<00:08, 14.37it/s]
# AMLX: No price data found, symbol may be delisted (period=7d)
# ELUT: No price data found, symbol may be delisted (period=7d)████████████████████▋ | 5070/5185 [05:12<00:09, 12.66it/s]
# BJRI: No price data found, symbol may be delisted (period=7d)
# NAVB: No price data found, symbol may be delisted (period=7d)
# VCNX: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'LAR' reason: Expecting value: line 1 column 1 (char 0)
# BHILQ: No price data found, symbol may be delisted (period=7d)
# ARCB: No price data found, symbol may be delisted (period=7d)
# PSIX: No price data found, symbol may be delisted (period=7d)████████████████████▊ | 5076/5185 [05:12<00:07, 13.76it/s]
# CXT: No price data found, symbol may be delisted (period=7d)
# GO: No price data found, symbol may be delisted (period=7d)
# PSX: No price data found, symbol may be delisted (period=7d)
# AMG: No price data found, symbol may be delisted (period=7d)
# SIF: No price data found, symbol may be delisted (period=7d)
# CPB: No price data found, symbol may be delisted (period=7d)
# KYMR: No price data found, symbol may be delisted (period=7d)████████████████████▉ | 5083/5185 [05:13<00:06, 15.40it/s]
# LAR: No price data found, symbol may be delisted (period=7d)
# HMPQ: No price data found, symbol may be delisted (period=7d)
# BBCP: No price data found, symbol may be delisted (period=7d)
# MDB: No price data found, symbol may be delisted (period=7d)
# DOLE: No price data found, symbol may be delisted (period=7d)████████████████████▉ | 5088/5185 [05:13<00:06, 14.87it/s]
# PKE: No price data found, symbol may be delisted (period=7d)
# AMRK: No price data found, symbol may be delisted (period=7d)
# CVKD: No price data found, symbol may be delisted (period=7d)
# TPG: No price data found, symbol may be delisted (period=7d)
# CWT: No price data found, symbol may be delisted (period=7d)
# INDP: No price data found, symbol may be delisted (period=7d)
# HROW: No price data found, symbol may be delisted (period=7d)████████████████████▉ | 5094/5185 [05:13<00:05, 15.28it/s]
# LVWR: No price data found, symbol may be delisted (period=7d)
# ENLV: No price data found, symbol may be delisted (period=7d)
# YMAB: No price data found, symbol may be delisted (period=7d)
# PBYI: No price data found, symbol may be delisted (period=7d)█████████████████████ | 5099/5185 [05:13<00:04, 18.82it/s]
# WABC: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'AQUC' reason: Expecting value: line 1 column 1 (char 0)
# CTOR: No price data found, symbol may be delisted (period=7d)
# ISTR: No price data found, symbol may be delisted (period=7d)█████████████████████ | 5102/5185 [05:14<00:04, 17.15it/s]
# RDAC: No price data found, symbol may be delisted (period=7d)
# TMDX: No price data found, symbol may be delisted (period=7d)
# OPRX: No price data found, symbol may be delisted (period=7d)
# WNS: No price data found, symbol may be delisted (period=7d)██████████████████████ | 5105/5185 [05:14<00:06, 13.02it/s]
# METCB: No price data found, symbol may be delisted (period=7d)
# AQUC: No price data found, symbol may be delisted (period=7d)
# VRAYQ: No price data found, symbol may be delisted (period=7d)
# FVCB: No price data found, symbol may be delisted (period=7d)█████████████████████▏| 5109/5185 [05:15<00:06, 12.03it/s]
# OSPN: No price data found, symbol may be delisted (period=7d)
# ZG: No price data found, symbol may be delisted (period=7d)
# VIRT: No price data found, symbol may be delisted (period=7d)
# ELOX: No price data found, symbol may be delisted (period=7d)█████████████████████▏| 5113/5185 [05:15<00:06, 11.92it/s]
# KZR: No price data found, symbol may be delisted (period=7d)
# SANG: No price data found, symbol may be delisted (period=7d)
# VGAS: No price data found, symbol may be delisted (period=7d)
# RS: No price data found, symbol may be delisted (period=7d)
# NCPCF: No price data found, symbol may be delisted (period=7d)
# INSP: No price data found, symbol may be delisted (period=7d)█████████████████████▎| 5119/5185 [05:15<00:05, 13.15it/s]
# HQY: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'SAIL' reason: Expecting value: line 1 column 1 (char 0)
# VVOS: No price data found, symbol may be delisted (period=7d)
# CPAY: No price data found, symbol may be delisted (period=7d)
# BOW: No price data found, symbol may be delisted (period=7d)██████████████████████▎| 5123/5185 [05:16<00:04, 12.65it/s]
# FMNB: No price data found, symbol may be delisted (period=7d)
# TTCM: No price data found, symbol may be delisted (period=7d)
# CCLD: No price data found, symbol may be delisted (period=7d)
# Validation progress:  99%|████████████████████████████████████████████████████████▎| 5128/5185 [05:16<00:04, 12.95it/s]PRM: No price data found, symbol may be delisted (period=7d)
# PBFS: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'LHSW' reason: Expecting value: line 1 column 1 (char 0)
# ORIS: No price data found, symbol may be delisted (period=7d)
# SAIL: No price data found, symbol may be delisted (period=7d)
# MRSN: No price data found, symbol may be delisted (period=7d)
# HUBB: No price data found, symbol may be delisted (period=7d)
# GRCE: No price data found, symbol may be delisted (period=7d)█████████████████████▍| 5134/5185 [05:16<00:03, 13.55it/s]
# BSRR: No price data found, symbol may be delisted (period=7d)
# AFRM: No price data found, symbol may be delisted (period=7d)
# HNNA: No price data found, symbol may be delisted (period=7d)
# LHSW: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'FGMC' reason: Expecting value: line 1 column 1 (char 0)█████▍| 5139/5185 [05:17<00:03, 13.58it/s]
# INTT: No price data found, symbol may be delisted (period=7d)
# HBB: No price data found, symbol may be delisted (period=7d)
# WWR: No price data found, symbol may be delisted (period=7d)
# AHCO: No price data found, symbol may be delisted (period=7d)
# GTIM: No price data found, symbol may be delisted (period=7d)
# PTPI: No price data found, symbol may be delisted (period=7d)
# ASIX: No price data found, symbol may be delisted (period=7d)█████████████████████▌| 5144/5185 [05:17<00:03, 13.51it/s]
# CRIS: No price data found, symbol may be delisted (period=7d)
# SATS: No price data found, symbol may be delisted (period=7d)
# FGMC: No price data found, symbol may be delisted (period=7d)
# BNIX: No price data found, symbol may be delisted (period=7d)
# IVRN: No price data found, symbol may be delisted (period=7d)
# MXL: No price data found, symbol may be delisted (period=7d)
# NHIQ: No price data found, symbol may be delisted (period=7d)█████████████████████▋| 5152/5185 [05:17<00:02, 15.95it/s]
# ZKIN: No price data found, symbol may be delisted (period=7d)
# CHGG: No price data found, symbol may be delisted (period=7d)
# FRST: No price data found, symbol may be delisted (period=7d)
# FRME: No price data found, symbol may be delisted (period=7d)█████████████████████▋| 5156/5185 [05:18<00:01, 14.55it/s]
# MDNAF: No price data found, symbol may be delisted (period=7d)
# YIBO: No price data found, symbol may be delisted (period=7d)
# LXRX: No price data found, symbol may be delisted (period=7d)
# ESSA: No price data found, symbol may be delisted (period=7d)
# ZS: No price data found, symbol may be delisted (period=7d)
# TK: No price data found, symbol may be delisted (period=7d)
# INSG: No price data found, symbol may be delisted (period=7d)█████████████████████▋| 5162/5185 [05:18<00:01, 15.05it/s]
# NXGL: No price data found, symbol may be delisted (period=7d)
# AZTR: No price data found, symbol may be delisted (period=7d)
# SRM: No price data found, symbol may be delisted (period=7d)██████████████████████▊| 5166/5185 [05:19<00:01, 13.77it/s]
# NISN: No price data found, symbol may be delisted (period=7d)
# MKDW: No price data found, symbol may be delisted (period=7d)
# MNRO: No price data found, symbol may be delisted (period=7d)
# VLY: No price data found, symbol may be delisted (period=7d)
# YELP: No price data found, symbol may be delisted (period=7d)
# BAC: No price data found, symbol may be delisted (period=7d)██████████████████████▊| 5172/5185 [05:19<00:00, 14.69it/s]
# GES: No price data found, symbol may be delisted (period=7d)
# LCFY: No price data found, symbol may be delisted (period=7d)
# CLDI: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'APTOF' reason: Expecting value: line 1 column 1 (char 0)
# SABR: No price data found, symbol may be delisted (period=7d)
# CNVIF: No price data found, symbol may be delisted (period=7d)████████████████████▉| 5177/5185 [05:19<00:00, 14.01it/s]
# AERT: No price data found, symbol may be delisted (period=7d)
# ELIQQ: No price data found, symbol may be delisted (period=7d)
# NPKI: No price data found, symbol may be delisted (period=7d)
# BBIO: No price data found, symbol may be delisted (period=7d)
# EVTC: No price data found, symbol may be delisted (period=7d)█████████████████████▉| 5181/5185 [05:20<00:00, 12.77it/s]
# BHB: No price data found, symbol may be delisted (period=7d)
# APTOF: No price data found, symbol may be delisted (period=7d)
# Validation progress: 100%|█████████████████████████████████████████████████████████| 5185/5185 [05:20<00:00, 16.17it/s]
# ✅ Valid tickers: 0, ❌ Invalid tickers: 5185
# 💾 Saving results...
# 📁 Filtered tickers saved to validated_tickers.xlsx
# ✅ Done. Moving to next cell (if supported)...

# %%
def main():
    input_file = "robinhood_tickers.xlsx"
    output_file = "validated_tickers.xlsx"

    print("📥 Loading tickers from Excel...")
    tickers = load_tickers_from_excel(input_file)

    print("🔍 Sample tickers before cleaning:", tickers[:10])  # 👀 Show raw tickers

    if not tickers:
        print("⚠️ No tickers found. Exiting...")
        return

    print("🧹 Cleaning ticker list...")
    tickers = clean_tickers(tickers)

    print("🧼 Cleaned tickers:", tickers[:10])  # 👀 Show cleaned tickers

    valid_tickers, invalid_tickers = validate_tickers_parallel(tickers)

    print("💾 Saving results...")
    save_filtered_tickers(valid_tickers, invalid_tickers, output_file)

    print("✅ Done.")

# Now call it to test
main()
# Out:
# 📥 Loading tickers from Excel...
# 🔍 Sample tickers before cleaning: ['JCSE', 'ARTV', 'ALTS', 'SNWV', 'WRLD', 'CSAI', 'CE', 'CRH', 'GLNG', 'TSQ']
# 🧹 Cleaning ticker list...
# 🧼 Cleaned tickers: ['JCSE', 'ARTV', 'ALTS', 'SNWV', 'WRLD', 'CSAI', 'CE', 'CRH', 'GLNG', 'TSQ']
# 🔍 Validating 5185 tickers using 10 threads...
# ARTV: No price data found, symbol may be delisted (period=7d)                                 | 0/5185 [00:00<?, ?it/s]
# JCSE: No price data found, symbol may be delisted (period=7d)                         | 1/5185 [00:00<30:27,  2.84it/s]
# ALTS: No price data found, symbol may be delisted (period=7d)
# WRLD: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'SNWV' reason: Expecting value: line 1 column 1 (char 0)
# CE: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'CSAI' reason: Expecting value: line 1 column 1 (char 0)
# CRH: No price data found, symbol may be delisted (period=7d)
# GLNG: No price data found, symbol may be delisted (period=7d)
# TSQ: No price data found, symbol may be delisted (period=7d)                          | 7/5185 [00:00<08:13, 10.48it/s]
# APXIF: No price data found, symbol may be delisted (period=7d)
# LGF.B: No price data found, symbol may be delisted (period=7d)
# SWKH: No price data found, symbol may be delisted (period=7d)                        | 10/5185 [00:01<09:02,  9.53it/s]
# YOSH: No price data found, symbol may be delisted (period=7d)
# CSAI: No price data found, symbol may be delisted (period=7d)
# J: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'NXUR' reason: Expecting value: line 1 column 1 (char 0)
# SNWV: No price data found, symbol may be delisted (period=7d)
# COLL: No price data found, symbol may be delisted (period=7d)
# VISL: No price data found, symbol may be delisted (period=7d)                        | 16/5185 [00:01<07:01, 12.26it/s]
# VSH: No price data found, symbol may be delisted (period=7d)
# DDS: No price data found, symbol may be delisted (period=7d)
# MCHX: No price data found, symbol may be delisted (period=7d)
# RVSB: No price data found, symbol may be delisted (period=7d)                        | 20/5185 [00:01<07:10, 11.98it/s]
# CVGW: No price data found, symbol may be delisted (period=7d)
# NPO: No price data found, symbol may be delisted (period=7d)
# NXUR: No price data found, symbol may be delisted (period=7d)
# IMAX: No price data found, symbol may be delisted (period=7d)
# MSN: No price data found, symbol may be delisted (period=7d)
# Validation progress:   1%|▎                                                          | 26/5185 [00:02<06:31, 13.18it/s]ACHV: No price data found, symbol may be delisted (period=7d)
# PMTS: No price data found, symbol may be delisted (period=7d)
# TFSL: No price data found, symbol may be delisted (period=7d)
# STNG: No price data found, symbol may be delisted (period=7d)
# MGNX: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'EVCO' reason: Expecting value: line 1 column 1 (char 0)
# LXEO: No price data found, symbol may be delisted (period=7d)
# TELO: No price data found, symbol may be delisted (period=7d)                        | 32/5185 [00:02<06:07, 14.03it/s]
# AMP: No price data found, symbol may be delisted (period=7d)
# ALGN: No price data found, symbol may be delisted (period=7d)
# TNET: No price data found, symbol may be delisted (period=7d)
# BOKF: No price data found, symbol may be delisted (period=7d)
# NRG: No price data found, symbol may be delisted (period=7d)                         | 37/5185 [00:02<06:05, 14.08it/s]
# TLYS: No price data found, symbol may be delisted (period=7d)
# ESI: No price data found, symbol may be delisted (period=7d)
# EVCO: No price data found, symbol may be delisted (period=7d)
# LPCN: No price data found, symbol may be delisted (period=7d)
# MDXG: No price data found, symbol may be delisted (period=7d)                        | 41/5185 [00:03<06:33, 13.06it/s]
# DFIN: No price data found, symbol may be delisted (period=7d)
# TTNP: No price data found, symbol may be delisted (period=7d)
# RGDXQ: No price data found, symbol may be delisted (period=7d)
# TEM: No price data found, symbol may be delisted (period=7d)
# TIOG: No price data found, symbol may be delisted (period=7d)
# JNJ: No price data found, symbol may be delisted (period=7d)                         | 48/5185 [00:03<05:48, 14.75it/s]
# ALLGF: No price data found, symbol may be delisted (period=7d)
# REZI: No price data found, symbol may be delisted (period=7d)
# FFIC: No price data found, symbol may be delisted (period=7d)                        | 51/5185 [00:04<06:30, 13.14it/s]
# Failed to get ticker 'CRD.B' reason: Expecting value: line 1 column 1 (char 0)
# SISI: No price data found, symbol may be delisted (period=7d)
# ALLK: No price data found, symbol may be delisted (period=7d)
# SUP: No price data found, symbol may be delisted (period=7d)
# CPA: No price data found, symbol may be delisted (period=7d)
# NCMI: No price data found, symbol may be delisted (period=7d)
# AZI: No price data found, symbol may be delisted (period=7d)
# KOD: No price data found, symbol may be delisted (period=7d)                         | 57/5185 [00:04<06:18, 13.54it/s]
# OFG: No price data found, symbol may be delisted (period=7d)
# MTRN: No price data found, symbol may be delisted (period=7d)
# BFST: No price data found, symbol may be delisted (period=7d)
# CRD.B: No price data found, symbol may be delisted (period=7d)
# FLYW: No price data found, symbol may be delisted (period=7d)
# CPHI: No price data found, symbol may be delisted (period=7d)
# AMBC: No price data found, symbol may be delisted (period=7d)
# BPMC: No price data found, symbol may be delisted (period=7d)                        | 66/5185 [00:05<06:14, 13.68it/s]
# GOLF: No price data found, symbol may be delisted (period=7d)
# CHEF: No price data found, symbol may be delisted (period=7d)                        | 68/5185 [00:05<07:20, 11.61it/s]
# GURE: No price data found, symbol may be delisted (period=7d)
# LMT: No price data found, symbol may be delisted (period=7d)
# CYCC: No price data found, symbol may be delisted (period=7d)
# MEIP: No price data found, symbol may be delisted (period=7d)
# MDT: No price data found, symbol may be delisted (period=7d)
# PFGC: No price data found, symbol may be delisted (period=7d)
# QTWO: No price data found, symbol may be delisted (period=7d)
# SSBI: No price data found, symbol may be delisted (period=7d)                        | 76/5185 [00:05<06:00, 14.18it/s]
# PMDI: No price data found, symbol may be delisted (period=7d)
# OCC: No price data found, symbol may be delisted (period=7d)
# AFMD: No price data found, symbol may be delisted (period=7d)
# INSE: No price data found, symbol may be delisted (period=7d)
# PTC: No price data found, symbol may be delisted (period=7d)
# Validation progress:   2%|▉                                                          | 82/5185 [00:06<05:42, 14.91it/s]YSXT: No price data found, symbol may be delisted (period=7d)
# UTRS: No price data found, symbol may be delisted (period=7d)
# MSBI: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'SFD' reason: Expecting value: line 1 column 1 (char 0)
# VANI: No price data found, symbol may be delisted (period=7d)
# NVTS: No price data found, symbol may be delisted (period=7d)                        | 86/5185 [00:06<06:11, 13.71it/s]
# TXN: No price data found, symbol may be delisted (period=7d)
# MCW: No price data found, symbol may be delisted (period=7d)
# MBLY: No price data found, symbol may be delisted (period=7d)
# VQSSF: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'CNR' reason: Expecting value: line 1 column 1 (char 0)
# XFOR: No price data found, symbol may be delisted (period=7d)
# Validation progress:   2%|█                                                          | 92/5185 [00:06<05:51, 14.49it/s]FCBC: No price data found, symbol may be delisted (period=7d)
# SFD: No price data found, symbol may be delisted (period=7d)
# SVVC: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'DXST' reason: Expecting value: line 1 column 1 (char 0)
# ALMS: No price data found, symbol may be delisted (period=7d)
# Validation progress:   2%|█                                                          | 96/5185 [00:07<06:12, 13.68it/s]Failed to get ticker 'CUTRQ' reason: Expecting value: line 1 column 1 (char 0)
# LFUS: No price data found, symbol may be delisted (period=7d)
# CNR: No price data found, symbol may be delisted (period=7d)
# CLBR: No price data found, symbol may be delisted (period=7d)
# PAGS: No price data found, symbol may be delisted (period=7d)
# NRIX: No price data found, symbol may be delisted (period=7d)
# RM: No price data found, symbol may be delisted (period=7d)                         | 100/5185 [00:07<06:35, 12.86it/s]
# PAX: No price data found, symbol may be delisted (period=7d)
# DXST: No price data found, symbol may be delisted (period=7d)
# ONEW: No price data found, symbol may be delisted (period=7d)
# CUTRQ: No price data found, symbol may be delisted (period=7d)
# BTCY: No price data found, symbol may be delisted (period=7d)
# Validation progress:   2%|█▏                                                        | 107/5185 [00:07<05:40, 14.92it/s]DD: No price data found, symbol may be delisted (period=7d)
# VLTO: No price data found, symbol may be delisted (period=7d)
# COCP: No price data found, symbol may be delisted (period=7d)
# RGLD: No price data found, symbol may be delisted (period=7d)
# GPLDF: No price data found, symbol may be delisted (period=7d)                      | 110/5185 [00:08<06:30, 12.99it/s]
# TLSI: No price data found, symbol may be delisted (period=7d)
# VTEX: No price data found, symbol may be delisted (period=7d)
# CLPT: No price data found, symbol may be delisted (period=7d)
# MEGEF: No price data found, symbol may be delisted (period=7d)
# ACTU: No price data found, symbol may be delisted (period=7d)
# IE: No price data found, symbol may be delisted (period=7d)
# WFCF: No price data found, symbol may be delisted (period=7d)                       | 117/5185 [00:08<05:39, 14.93it/s]
# JMSB: No price data found, symbol may be delisted (period=7d)
# IPSC: No price data found, symbol may be delisted (period=7d)
# BLFS: No price data found, symbol may be delisted (period=7d)
# BPOP: No price data found, symbol may be delisted (period=7d)
# WFRD: No price data found, symbol may be delisted (period=7d)
# VFC: No price data found, symbol may be delisted (period=7d)
# PLTR: No price data found, symbol may be delisted (period=7d)
# SPHL: No price data found, symbol may be delisted (period=7d)                       | 124/5185 [00:09<05:19, 15.86it/s]
# GNE: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'CUPR' reason: Expecting value: line 1 column 1 (char 0)       | 127/5185 [00:09<06:09, 13.71it/s]
# OGN: No price data found, symbol may be delisted (period=7d)
# YHC: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'BH.A' reason: Expecting value: line 1 column 1 (char 0)
# EL: No price data found, symbol may be delisted (period=7d)
# PCG: No price data found, symbol may be delisted (period=7d)
# NATL: No price data found, symbol may be delisted (period=7d)
# LWLG: No price data found, symbol may be delisted (period=7d)                       | 132/5185 [00:09<06:13, 13.52it/s]
# STAI: No price data found, symbol may be delisted (period=7d)
# CNTM: No price data found, symbol may be delisted (period=7d)
# CUPR: No price data found, symbol may be delisted (period=7d)                       | 135/5185 [00:10<07:02, 11.96it/s]
# LTRY: No price data found, symbol may be delisted (period=7d)
# IP: No price data found, symbol may be delisted (period=7d)
# BH.A: No price data found, symbol may be delisted (period=7d)
# VENU: No price data found, symbol may be delisted (period=7d)
# TBMC: No price data found, symbol may be delisted (period=7d)
# BRY: No price data found, symbol may be delisted (period=7d)                        | 142/5185 [00:10<06:06, 13.75it/s]
# IGTA: No price data found, symbol may be delisted (period=7d)
# SPTN: No price data found, symbol may be delisted (period=7d)
# NOW: No price data found, symbol may be delisted (period=7d)                        | 145/5185 [00:10<06:45, 12.44it/s]
# SGRY: No price data found, symbol may be delisted (period=7d)
# GWRS: No price data found, symbol may be delisted (period=7d)
# TUEMQ: No price data found, symbol may be delisted (period=7d)
# TSN: No price data found, symbol may be delisted (period=7d)
# BEEP: No price data found, symbol may be delisted (period=7d)
# AIP: No price data found, symbol may be delisted (period=7d)
# PINC: No price data found, symbol may be delisted (period=7d)
# WSBC: No price data found, symbol may be delisted (period=7d)                       | 153/5185 [00:11<05:33, 15.11it/s]
# NWSA: No price data found, symbol may be delisted (period=7d)
# GTN: No price data found, symbol may be delisted (period=7d)
# KRUS: No price data found, symbol may be delisted (period=7d)
# CSL: No price data found, symbol may be delisted (period=7d)
# SXTP: No price data found, symbol may be delisted (period=7d)
# RBBN: No price data found, symbol may be delisted (period=7d)
# MGAM: No price data found, symbol may be delisted (period=7d)
# THRY: No price data found, symbol may be delisted (period=7d)                       | 161/5185 [00:11<04:55, 17.00it/s]
# OZK: No price data found, symbol may be delisted (period=7d)
# NOG: No price data found, symbol may be delisted (period=7d)
# RIOT: No price data found, symbol may be delisted (period=7d)
# ESTRF: No price data found, symbol may be delisted (period=7d)                      | 164/5185 [00:12<05:44, 14.57it/s]
# PRVA: No price data found, symbol may be delisted (period=7d)
# ONCO: No price data found, symbol may be delisted (period=7d)
# CPIX: No price data found, symbol may be delisted (period=7d)
# ELMSQ: No price data found, symbol may be delisted (period=7d)
# FLGC: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'DNMRQ' reason: Expecting value: line 1 column 1 (char 0)      | 171/5185 [00:12<05:02, 16.60it/s]
# OTEX: No price data found, symbol may be delisted (period=7d)
# MMVVF: No price data found, symbol may be delisted (period=7d)
# AENT: No price data found, symbol may be delisted (period=7d)                       | 173/5185 [00:12<06:33, 12.74it/s]
# DNMRQ: No price data found, symbol may be delisted (period=7d)
# TATT: No price data found, symbol may be delisted (period=7d)
# SCM: No price data found, symbol may be delisted (period=7d)
# IZM: No price data found, symbol may be delisted (period=7d)
# PRCH: No price data found, symbol may be delisted (period=7d)
# CRTD: No price data found, symbol may be delisted (period=7d)
# POAI: No price data found, symbol may be delisted (period=7d)
# XRX: No price data found, symbol may be delisted (period=7d)
# WBA: No price data found, symbol may be delisted (period=7d)                        | 182/5185 [00:13<05:11, 16.04it/s]
# RAPP: No price data found, symbol may be delisted (period=7d)
# KN: No price data found, symbol may be delisted (period=7d)
# NCL: No price data found, symbol may be delisted (period=7d)
# FTCI: No price data found, symbol may be delisted (period=7d)                       | 185/5185 [00:13<06:02, 13.81it/s]
# ESAB: No price data found, symbol may be delisted (period=7d)
# BODI: No price data found, symbol may be delisted (period=7d)
# SOQDQ: No price data found, symbol may be delisted (period=7d)
# HLX: No price data found, symbol may be delisted (period=7d)
# ILAG: No price data found, symbol may be delisted (period=7d)
# CRMT: No price data found, symbol may be delisted (period=7d)
# BRSHF: No price data found, symbol may be delisted (period=7d)                      | 193/5185 [00:13<05:10, 16.10it/s]
# HAYW: No price data found, symbol may be delisted (period=7d)
# CCEP: No price data found, symbol may be delisted (period=7d)
# MHUA: No price data found, symbol may be delisted (period=7d)
# JOBY: No price data found, symbol may be delisted (period=7d)
# ASTI: No price data found, symbol may be delisted (period=7d)
# MMNFQ: No price data found, symbol may be delisted (period=7d)
# SLP: No price data found, symbol may be delisted (period=7d)
# MOD: No price data found, symbol may be delisted (period=7d)
# DOCN: No price data found, symbol may be delisted (period=7d)                       | 201/5185 [00:14<04:39, 17.81it/s]
# FSS: No price data found, symbol may be delisted (period=7d)                        | 203/5185 [00:14<05:45, 14.43it/s]
# AWIN: No price data found, symbol may be delisted (period=7d)
# VIAV: No price data found, symbol may be delisted (period=7d)
# LEGH: No price data found, symbol may be delisted (period=7d)
# ULCC: No price data found, symbol may be delisted (period=7d)
# LGVN: No price data found, symbol may be delisted (period=7d)
# TPST: No price data found, symbol may be delisted (period=7d)
# PLBC: No price data found, symbol may be delisted (period=7d)
# BAM: No price data found, symbol may be delisted (period=7d)
# Validation progress:   4%|██▎                                                       | 211/5185 [00:14<05:04, 16.32it/s]JOUT: No price data found, symbol may be delisted (period=7d)
# ZYME: No price data found, symbol may be delisted (period=7d)
# FYBR: No price data found, symbol may be delisted (period=7d)
# ENGN: No price data found, symbol may be delisted (period=7d)                       | 215/5185 [00:15<05:32, 14.95it/s]
# PARAA: No price data found, symbol may be delisted (period=7d)
# MOS: No price data found, symbol may be delisted (period=7d)
# QURE: No price data found, symbol may be delisted (period=7d)
# PITA: No price data found, symbol may be delisted (period=7d)
# LNTH: No price data found, symbol may be delisted (period=7d)
# AER: No price data found, symbol may be delisted (period=7d)                        | 221/5185 [00:15<05:19, 15.53it/s]
# ANGO: No price data found, symbol may be delisted (period=7d)
# GSBD: No price data found, symbol may be delisted (period=7d)
# LIPO: No price data found, symbol may be delisted (period=7d)
# MSS: No price data found, symbol may be delisted (period=7d)
# PRI: No price data found, symbol may be delisted (period=7d)                        | 226/5185 [00:16<05:34, 14.82it/s]
# NLSP: No price data found, symbol may be delisted (period=7d)
# DTI: No price data found, symbol may be delisted (period=7d)
# OPY: No price data found, symbol may be delisted (period=7d)
# DNLI: No price data found, symbol may be delisted (period=7d)
# CAMP: No price data found, symbol may be delisted (period=7d)
# MVBF: No price data found, symbol may be delisted (period=7d)
# EOLS: No price data found, symbol may be delisted (period=7d)
# LSTR: No price data found, symbol may be delisted (period=7d)                       | 234/5185 [00:16<04:55, 16.74it/s]
# NEUE: No price data found, symbol may be delisted (period=7d)
# DSGX: No price data found, symbol may be delisted (period=7d)
# FITB: No price data found, symbol may be delisted (period=7d)
# LUCY: No price data found, symbol may be delisted (period=7d)                       | 237/5185 [00:16<05:50, 14.13it/s]
# ANEB: No price data found, symbol may be delisted (period=7d)
# PRPL: No price data found, symbol may be delisted (period=7d)
# QGEN: No price data found, symbol may be delisted (period=7d)
# HOPE: No price data found, symbol may be delisted (period=7d)
# PEN: No price data found, symbol may be delisted (period=7d)
# EMCG: No price data found, symbol may be delisted (period=7d)                       | 244/5185 [00:17<05:15, 15.67it/s]
# GMBL: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'TETEF' reason: Expecting value: line 1 column 1 (char 0)
# MAMA: No price data found, symbol may be delisted (period=7d)
# GPRE: No price data found, symbol may be delisted (period=7d)                       | 247/5185 [00:17<06:07, 13.43it/s]
# AMR: No price data found, symbol may be delisted (period=7d)
# ELDN: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'XYZ' reason: Expecting value: line 1 column 1 (char 0)
# PRTS: No price data found, symbol may be delisted (period=7d)
# STLA: No price data found, symbol may be delisted (period=7d)
# TPH: No price data found, symbol may be delisted (period=7d)
# BV: No price data found, symbol may be delisted (period=7d)
# TETEF: No price data found, symbol may be delisted (period=7d)                      | 253/5185 [00:17<05:48, 14.17it/s]
# ADPT: No price data found, symbol may be delisted (period=7d)
# MDAI: No price data found, symbol may be delisted (period=7d)
# UP: No price data found, symbol may be delisted (period=7d)
# FOA: No price data found, symbol may be delisted (period=7d)                        | 257/5185 [00:18<06:16, 13.08it/s]
# XYZ: No price data found, symbol may be delisted (period=7d)
# THM: No price data found, symbol may be delisted (period=7d)
# YUM: No price data found, symbol may be delisted (period=7d)
# BRO: No price data found, symbol may be delisted (period=7d)
# AGI: No price data found, symbol may be delisted (period=7d)
# GP: No price data found, symbol may be delisted (period=7d)                         | 263/5185 [00:18<05:50, 14.03it/s]
# RLAY: No price data found, symbol may be delisted (period=7d)
# AROW: No price data found, symbol may be delisted (period=7d)
# Validation progress:   5%|██▉                                                       | 267/5185 [00:19<06:10, 13.29it/s]TNC: No price data found, symbol may be delisted (period=7d)
# CCIR: No price data found, symbol may be delisted (period=7d)
# BTOC: No price data found, symbol may be delisted (period=7d)
# TBPH: No price data found, symbol may be delisted (period=7d)
# ZETA: No price data found, symbol may be delisted (period=7d)
# HSCS: No price data found, symbol may be delisted (period=7d)
# LSDIF: No price data found, symbol may be delisted (period=7d)
# TNEN: No price data found, symbol may be delisted (period=7d)
# VKTX: No price data found, symbol may be delisted (period=7d)
# PAYX: No price data found, symbol may be delisted (period=7d)                       | 273/5185 [00:19<05:47, 14.13it/s]
# COOP: No price data found, symbol may be delisted (period=7d)
# ALTI: No price data found, symbol may be delisted (period=7d)                       | 278/5185 [00:19<05:46, 14.14it/s]
# PFS: No price data found, symbol may be delisted (period=7d)
# YRIV: No price data found, symbol may be delisted (period=7d)
# CBSH: No price data found, symbol may be delisted (period=7d)
# CARR: No price data found, symbol may be delisted (period=7d)
# Validation progress:   5%|███▏                                                      | 283/5185 [00:20<05:47, 14.09it/s]CODA: No price data found, symbol may be delisted (period=7d)
# RAPT: No price data found, symbol may be delisted (period=7d)
# RYI: No price data found, symbol may be delisted (period=7d)
# FND: No price data found, symbol may be delisted (period=7d)
# PAPL: No price data found, symbol may be delisted (period=7d)
# ABNB: No price data found, symbol may be delisted (period=7d)
# PSBD: No price data found, symbol may be delisted (period=7d)
# Validation progress:   6%|███▏                                                      | 289/5185 [00:20<05:34, 14.65it/s]BRZE: No price data found, symbol may be delisted (period=7d)
# ASLE: No price data found, symbol may be delisted (period=7d)
# VLN: No price data found, symbol may be delisted (period=7d)
# BBGI: No price data found, symbol may be delisted (period=7d)
# OCUL: No price data found, symbol may be delisted (period=7d)                       | 294/5185 [00:20<05:35, 14.58it/s]
# EVBN: No price data found, symbol may be delisted (period=7d)
# MANH: No price data found, symbol may be delisted (period=7d)
# FBLG: No price data found, symbol may be delisted (period=7d)
# BNRG: No price data found, symbol may be delisted (period=7d)
# UNCY: No price data found, symbol may be delisted (period=7d)                       | 299/5185 [00:21<05:48, 14.03it/s]
# MHK: No price data found, symbol may be delisted (period=7d)
# ATS: No price data found, symbol may be delisted (period=7d)
# SSBK: No price data found, symbol may be delisted (period=7d)
# ACNB: No price data found, symbol may be delisted (period=7d)
# ADT: No price data found, symbol may be delisted (period=7d)                        | 304/5185 [00:21<05:47, 14.05it/s]
# AONC: No price data found, symbol may be delisted (period=7d)
# WTS: No price data found, symbol may be delisted (period=7d)
# DHI: No price data found, symbol may be delisted (period=7d)
# LEE: No price data found, symbol may be delisted (period=7d)
# INO: No price data found, symbol may be delisted (period=7d)
# HCAT: No price data found, symbol may be delisted (period=7d)                       | 309/5185 [00:21<06:09, 13.20it/s]
# TRSG: No price data found, symbol may be delisted (period=7d)
# AUBN: No price data found, symbol may be delisted (period=7d)
# PPSI: No price data found, symbol may be delisted (period=7d)
# RDIB: No price data found, symbol may be delisted (period=7d)
# BKE: No price data found, symbol may be delisted (period=7d)
# Validation progress:   6%|███▌                                                      | 315/5185 [00:22<05:39, 14.36it/s]OPRT: No price data found, symbol may be delisted (period=7d)
# UTMD: No price data found, symbol may be delisted (period=7d)
# INTR: No price data found, symbol may be delisted (period=7d)
# CCOI: No price data found, symbol may be delisted (period=7d)                       | 319/5185 [00:22<06:13, 13.05it/s]
# FA: No price data found, symbol may be delisted (period=7d)
# FTHM: No price data found, symbol may be delisted (period=7d)
# AMCR: No price data found, symbol may be delisted (period=7d)
# RUSHB: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'CJMB' reason: Expecting value: line 1 column 1 (char 0)
# JHG: No price data found, symbol may be delisted (period=7d)
# Validation progress:   6%|███▋                                                      | 325/5185 [00:23<05:43, 14.14it/s]ATRA: No price data found, symbol may be delisted (period=7d)
# KALV: No price data found, symbol may be delisted (period=7d)
# SVBL: No price data found, symbol may be delisted (period=7d)
# Validation progress:   6%|███▋                                                      | 328/5185 [00:23<06:29, 12.47it/s]KSCP: No price data found, symbol may be delisted (period=7d)
# XXII: No price data found, symbol may be delisted (period=7d)
# DGX: No price data found, symbol may be delisted (period=7d)
# OTTV: No price data found, symbol may be delisted (period=7d)
# DOCU: No price data found, symbol may be delisted (period=7d)
# CJMB: No price data found, symbol may be delisted (period=7d)
# LKFN: No price data found, symbol may be delisted (period=7d)                       | 334/5185 [00:23<06:00, 13.45it/s]
# MBOT: No price data found, symbol may be delisted (period=7d)
# WGS: No price data found, symbol may be delisted (period=7d)
# OCTO: No price data found, symbol may be delisted (period=7d)
# Validation progress:   7%|███▊                                                      | 338/5185 [00:24<06:29, 12.43it/s]BBXIA: No price data found, symbol may be delisted (period=7d)
# STGW: No price data found, symbol may be delisted (period=7d)
# MGPI: No price data found, symbol may be delisted (period=7d)
# WMG: No price data found, symbol may be delisted (period=7d)
# PLUG: No price data found, symbol may be delisted (period=7d)
# FHB: No price data found, symbol may be delisted (period=7d)
# EOSE: No price data found, symbol may be delisted (period=7d)
# IMMX: No price data found, symbol may be delisted (period=7d)                       | 345/5185 [00:24<05:38, 14.29it/s]
# EBMT: No price data found, symbol may be delisted (period=7d)
# NWBI: No price data found, symbol may be delisted (period=7d)
# LINUF: No price data found, symbol may be delisted (period=7d)                      | 348/5185 [00:24<06:29, 12.42it/s]
# AFYA: No price data found, symbol may be delisted (period=7d)
# HOOD: No price data found, symbol may be delisted (period=7d)
# BANR: No price data found, symbol may be delisted (period=7d)
# SWSS: No price data found, symbol may be delisted (period=7d)
# PLNT: No price data found, symbol may be delisted (period=7d)
# MED: No price data found, symbol may be delisted (period=7d)
# HPAI: No price data found, symbol may be delisted (period=7d)                       | 355/5185 [00:25<05:39, 14.25it/s]
# LSAK: No price data found, symbol may be delisted (period=7d)
# PPC: No price data found, symbol may be delisted (period=7d)
# GASS: No price data found, symbol may be delisted (period=7d)
# BGC: No price data found, symbol may be delisted (period=7d)                        | 359/5185 [00:25<06:05, 13.20it/s]
# SXC: No price data found, symbol may be delisted (period=7d)
# ZCMD: No price data found, symbol may be delisted (period=7d)
# VRME: No price data found, symbol may be delisted (period=7d)
# COP: No price data found, symbol may be delisted (period=7d)
# STTO: No price data found, symbol may be delisted (period=7d)
# CYTOF: No price data found, symbol may be delisted (period=7d)
# IGC: No price data found, symbol may be delisted (period=7d)
# HNRG: No price data found, symbol may be delisted (period=7d)                       | 366/5185 [00:26<05:24, 14.86it/s]
# LMPX: No price data found, symbol may be delisted (period=7d)
# PHIN: No price data found, symbol may be delisted (period=7d)
# BLUAF: No price data found, symbol may be delisted (period=7d)                      | 370/5185 [00:26<05:46, 13.88it/s]
# BBSI: No price data found, symbol may be delisted (period=7d)
# COTY: No price data found, symbol may be delisted (period=7d)
# PR: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'PN' reason: Expecting value: line 1 column 1 (char 0)
# IR: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'CRD.A' reason: Expecting value: line 1 column 1 (char 0)
# DYN: No price data found, symbol may be delisted (period=7d)                        | 375/5185 [00:26<05:57, 13.46it/s]
# BEAG: No price data found, symbol may be delisted (period=7d)
# SKYE: No price data found, symbol may be delisted (period=7d)
# THCH: No price data found, symbol may be delisted (period=7d)
# ABOS: No price data found, symbol may be delisted (period=7d)
# ALDF: No price data found, symbol may be delisted (period=7d)
# VTLE: No price data found, symbol may be delisted (period=7d)                       | 381/5185 [00:27<05:31, 14.51it/s]
# PN: No price data found, symbol may be delisted (period=7d)
# XP: No price data found, symbol may be delisted (period=7d)
# WEJOF: No price data found, symbol may be delisted (period=7d)                      | 384/5185 [00:27<06:19, 12.65it/s]
# NEU: No price data found, symbol may be delisted (period=7d)
# AAME: No price data found, symbol may be delisted (period=7d)
# WLDS: No price data found, symbol may be delisted (period=7d)
# CRD.A: No price data found, symbol may be delisted (period=7d)
# VYNE: No price data found, symbol may be delisted (period=7d)
# YAAS: No price data found, symbol may be delisted (period=7d)
# RGEN: No price data found, symbol may be delisted (period=7d)                       | 391/5185 [00:27<05:37, 14.21it/s]
# ITRN: No price data found, symbol may be delisted (period=7d)
# CERS: No price data found, symbol may be delisted (period=7d)
# CFBK: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'ASBP' reason: Expecting value: line 1 column 1 (char 0)       | 395/5185 [00:28<06:00, 13.29it/s]
# DMAC: No price data found, symbol may be delisted (period=7d)
# RAIL: No price data found, symbol may be delisted (period=7d)
# GORO: No price data found, symbol may be delisted (period=7d)
# THTX: No price data found, symbol may be delisted (period=7d)
# ORRF: No price data found, symbol may be delisted (period=7d)
# MCOM: No price data found, symbol may be delisted (period=7d)
# Validation progress:   8%|████▍                                                     | 401/5185 [00:28<05:37, 14.17it/s]BTMD: No price data found, symbol may be delisted (period=7d)
# FVRR: No price data found, symbol may be delisted (period=7d)
# ASBP: No price data found, symbol may be delisted (period=7d)
# CWK: No price data found, symbol may be delisted (period=7d)
# SLQT: No price data found, symbol may be delisted (period=7d)
# CAPR: No price data found, symbol may be delisted (period=7d)
# ALT: No price data found, symbol may be delisted (period=7d)                        | 407/5185 [00:29<05:26, 14.62it/s]
# ULY: No price data found, symbol may be delisted (period=7d)
# JELD: No price data found, symbol may be delisted (period=7d)
# RCL: No price data found, symbol may be delisted (period=7d)
# PCOR: No price data found, symbol may be delisted (period=7d)
# BTG: No price data found, symbol may be delisted (period=7d)
# OPOF: No price data found, symbol may be delisted (period=7d)                       | 412/5185 [00:29<05:27, 14.57it/s]
# BCG: No price data found, symbol may be delisted (period=7d)
# PYXS: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'MKC.V' reason: Expecting value: line 1 column 1 (char 0)
# MGHL: No price data found, symbol may be delisted (period=7d)
# SERA: No price data found, symbol may be delisted (period=7d)                       | 417/5185 [00:29<05:34, 14.26it/s]
# PC: No price data found, symbol may be delisted (period=7d)
# DGLY: No price data found, symbol may be delisted (period=7d)
# SMMT: No price data found, symbol may be delisted (period=7d)
# FUL: No price data found, symbol may be delisted (period=7d)
# COST: No price data found, symbol may be delisted (period=7d)                       | 421/5185 [00:30<06:02, 13.16it/s]
# OPTN: No price data found, symbol may be delisted (period=7d)
# SPEC: No price data found, symbol may be delisted (period=7d)
# SSUNF: No price data found, symbol may be delisted (period=7d)
# MKC.V: No price data found, symbol may be delisted (period=7d)
# LIEN: No price data found, symbol may be delisted (period=7d)                       | 426/5185 [00:30<05:47, 13.71it/s]
# CRL: No price data found, symbol may be delisted (period=7d)
# ORGS: No price data found, symbol may be delisted (period=7d)
# BCBP: No price data found, symbol may be delisted (period=7d)
# MTH: No price data found, symbol may be delisted (period=7d)
# PWM: No price data found, symbol may be delisted (period=7d)
# ASST: No price data found, symbol may be delisted (period=7d)                       | 431/5185 [00:30<05:57, 13.32it/s]
# DE: No price data found, symbol may be delisted (period=7d)
# ROMA: No price data found, symbol may be delisted (period=7d)
# HOG: No price data found, symbol may be delisted (period=7d)
# TNL: No price data found, symbol may be delisted (period=7d)
# Validation progress:   8%|████▉                                                     | 438/5185 [00:31<05:25, 14.60it/s]WATT: No price data found, symbol may be delisted (period=7d)
# VMD: No price data found, symbol may be delisted (period=7d)
# LZ: No price data found, symbol may be delisted (period=7d)
# META: No price data found, symbol may be delisted (period=7d)
# FWRG: No price data found, symbol may be delisted (period=7d)                       | 441/5185 [00:31<06:15, 12.63it/s]
# GFR: No price data found, symbol may be delisted (period=7d)
# FOXO: No price data found, symbol may be delisted (period=7d)
# STLD: No price data found, symbol may be delisted (period=7d)
# CP: No price data found, symbol may be delisted (period=7d)
# ARQQ: No price data found, symbol may be delisted (period=7d)
# Validation progress:   9%|█████                                                     | 448/5185 [00:32<05:23, 14.64it/s]GRC: No price data found, symbol may be delisted (period=7d)
# LOCM: No price data found, symbol may be delisted (period=7d)
# CUEN: No price data found, symbol may be delisted (period=7d)
# SYRS: No price data found, symbol may be delisted (period=7d)
# ELA: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'MAYA' reason: Expecting value: line 1 column 1 (char 0)       | 451/5185 [00:32<06:12, 12.71it/s]
# BRLT: No price data found, symbol may be delisted (period=7d)
# ICCT: No price data found, symbol may be delisted (period=7d)
# LOB: No price data found, symbol may be delisted (period=7d)
# PUCK: No price data found, symbol may be delisted (period=7d)
# PRLD: No price data found, symbol may be delisted (period=7d)                       | 457/5185 [00:32<05:35, 14.09it/s]
# SWAG: No price data found, symbol may be delisted (period=7d)
# ASPI: No price data found, symbol may be delisted (period=7d)
# TTMI: No price data found, symbol may be delisted (period=7d)
# Validation progress:   9%|█████▏                                                    | 460/5185 [00:33<06:29, 12.14it/s]MSAI: No price data found, symbol may be delisted (period=7d)
# MAYA: No price data found, symbol may be delisted (period=7d)
# NAOV: No price data found, symbol may be delisted (period=7d)
# MDRX: No price data found, symbol may be delisted (period=7d)
# SENS: No price data found, symbol may be delisted (period=7d)
# PRDO: No price data found, symbol may be delisted (period=7d)
# GALT: No price data found, symbol may be delisted (period=7d)
# SLHGF: No price data found, symbol may be delisted (period=7d)                      | 468/5185 [00:33<05:08, 15.27it/s]
# CLMB: No price data found, symbol may be delisted (period=7d)
# RENO: No price data found, symbol may be delisted (period=7d)                       | 470/5185 [00:33<06:18, 12.45it/s]
# EVCM: No price data found, symbol may be delisted (period=7d)
# KLC: No price data found, symbol may be delisted (period=7d)
# ELAB: No price data found, symbol may be delisted (period=7d)
# BMRN: No price data found, symbol may be delisted (period=7d)
# SCNX: No price data found, symbol may be delisted (period=7d)
# LEXX: No price data found, symbol may be delisted (period=7d)
# ALGT: No price data found, symbol may be delisted (period=7d)
# SMP: No price data found, symbol may be delisted (period=7d)
# FDX: No price data found, symbol may be delisted (period=7d)
# BC: No price data found, symbol may be delisted (period=7d)
# HSII: No price data found, symbol may be delisted (period=7d)                       | 480/5185 [00:34<04:57, 15.84it/s]
# SCPH: No price data found, symbol may be delisted (period=7d)
# ACVA: No price data found, symbol may be delisted (period=7d)
# SNOA: No price data found, symbol may be delisted (period=7d)
# REE: No price data found, symbol may be delisted (period=7d)
# EJH: No price data found, symbol may be delisted (period=7d)
# AVA: No price data found, symbol may be delisted (period=7d)
# GTBP: No price data found, symbol may be delisted (period=7d)
# FINW: No price data found, symbol may be delisted (period=7d)
# Validation progress:   9%|█████▍                                                    | 490/5185 [00:34<04:30, 17.38it/s]SIGA: No price data found, symbol may be delisted (period=7d)
# BEEM: No price data found, symbol may be delisted (period=7d)
# REX: No price data found, symbol may be delisted (period=7d)
# AL: No price data found, symbol may be delisted (period=7d)
# HALO: No price data found, symbol may be delisted (period=7d)
# FLUX: No price data found, symbol may be delisted (period=7d)
# FNLC: No price data found, symbol may be delisted (period=7d)
# WBD: No price data found, symbol may be delisted (period=7d)
# FBK: No price data found, symbol may be delisted (period=7d)
# ATNI: No price data found, symbol may be delisted (period=7d)
# Validation progress:  10%|█████▌                                                    | 500/5185 [00:35<04:07, 18.96it/s]DPZ: No price data found, symbol may be delisted (period=7d)
# PETZ: No price data found, symbol may be delisted (period=7d)
# CRDO: No price data found, symbol may be delisted (period=7d)
# HFFG: No price data found, symbol may be delisted (period=7d)
# SNFCA: No price data found, symbol may be delisted (period=7d)
# ENVB: No price data found, symbol may be delisted (period=7d)
# GDEV: No price data found, symbol may be delisted (period=7d)
# BAOS: No price data found, symbol may be delisted (period=7d)
# GNLX: No price data found, symbol may be delisted (period=7d)
# AZTA: No price data found, symbol may be delisted (period=7d)
# PEGA: No price data found, symbol may be delisted (period=7d)                       | 510/5185 [00:35<03:49, 20.34it/s]
# NOTV: No price data found, symbol may be delisted (period=7d)
# UOKA: No price data found, symbol may be delisted (period=7d)
# CDRE: No price data found, symbol may be delisted (period=7d)
# CELU: No price data found, symbol may be delisted (period=7d)
# CDVIQ: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'LUD' reason: Expecting value: line 1 column 1 (char 0)
# LARK: No price data found, symbol may be delisted (period=7d)
# AFIIQ: No price data found, symbol may be delisted (period=7d)
# BITCF: No price data found, symbol may be delisted (period=7d)
# Validation progress:  10%|█████▊                                                    | 519/5185 [00:36<03:44, 20.74it/s]LUD: No price data found, symbol may be delisted (period=7d)
# CNET: No price data found, symbol may be delisted (period=7d)
# TRVI: No price data found, symbol may be delisted (period=7d)
# GXO: No price data found, symbol may be delisted (period=7d)
# COO: No price data found, symbol may be delisted (period=7d)
# BRKL: No price data found, symbol may be delisted (period=7d)
# ATI: No price data found, symbol may be delisted (period=7d)
# PAY: No price data found, symbol may be delisted (period=7d)
# ZION: No price data found, symbol may be delisted (period=7d)
# EGLXF: No price data found, symbol may be delisted (period=7d)
# DCGO: No price data found, symbol may be delisted (period=7d)                       | 529/5185 [00:36<03:37, 21.39it/s]
# CMBT: No price data found, symbol may be delisted (period=7d)
# TEN: No price data found, symbol may be delisted (period=7d)
# PRAA: No price data found, symbol may be delisted (period=7d)
# CBNA: No price data found, symbol may be delisted (period=7d)
# IPI: No price data found, symbol may be delisted (period=7d)
# BH: No price data found, symbol may be delisted (period=7d)
# CRNT: No price data found, symbol may be delisted (period=7d)
# STX: No price data found, symbol may be delisted (period=7d)
# KAPA: No price data found, symbol may be delisted (period=7d)
# CZNC: No price data found, symbol may be delisted (period=7d)                       | 539/5185 [00:36<03:31, 21.94it/s]
# Failed to get ticker 'ZOMDF' reason: Expecting value: line 1 column 1 (char 0)
# ARCO: No price data found, symbol may be delisted (period=7d)
# SITE: No price data found, symbol may be delisted (period=7d)
# MATW: No price data found, symbol may be delisted (period=7d)
# PHAT: No price data found, symbol may be delisted (period=7d)
# EDMCQ: No price data found, symbol may be delisted (period=7d)
# WSO: No price data found, symbol may be delisted (period=7d)
# WERN: No price data found, symbol may be delisted (period=7d)
# GENC: No price data found, symbol may be delisted (period=7d)
# SKIL: No price data found, symbol may be delisted (period=7d)                       | 548/5185 [00:37<03:33, 21.74it/s]
# ATER: No price data found, symbol may be delisted (period=7d)
# LNKB: No price data found, symbol may be delisted (period=7d)
# MRUS: No price data found, symbol may be delisted (period=7d)
# HEI: No price data found, symbol may be delisted (period=7d)
# OGE: No price data found, symbol may be delisted (period=7d)
# ZOMDF: No price data found, symbol may be delisted (period=7d)
# CCRD: No price data found, symbol may be delisted (period=7d)
# WAT: No price data found, symbol may be delisted (period=7d)
# BWFG: No price data found, symbol may be delisted (period=7d)
# Validation progress:  11%|██████▏                                                   | 558/5185 [00:37<03:36, 21.39it/s]ONFO: No price data found, symbol may be delisted (period=7d)
# UTSI: No price data found, symbol may be delisted (period=7d)
# ZBH: No price data found, symbol may be delisted (period=7d)
# PCB: No price data found, symbol may be delisted (period=7d)
# OPXS: No price data found, symbol may be delisted (period=7d)
# LTBR: No price data found, symbol may be delisted (period=7d)
# MSW: No price data found, symbol may be delisted (period=7d)
# LFST: No price data found, symbol may be delisted (period=7d)
# RICK: No price data found, symbol may be delisted (period=7d)
# HRL: No price data found, symbol may be delisted (period=7d)
# Validation progress:  11%|██████▎                                                   | 568/5185 [00:38<03:32, 21.73it/s]TPVG: No price data found, symbol may be delisted (period=7d)
# OLB: No price data found, symbol may be delisted (period=7d)
# WELNF: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'XAGE' reason: Expecting value: line 1 column 1 (char 0)
# DNUT: No price data found, symbol may be delisted (period=7d)
# LSB: No price data found, symbol may be delisted (period=7d)
# Z: No price data found, symbol may be delisted (period=7d)
# LC: No price data found, symbol may be delisted (period=7d)
# LYRA: No price data found, symbol may be delisted (period=7d)
# BBW: No price data found, symbol may be delisted (period=7d)
# MGHCF: No price data found, symbol may be delisted (period=7d)                      | 577/5185 [00:38<03:34, 21.48it/s]
# XAGE: No price data found, symbol may be delisted (period=7d)
# IDXG: No price data found, symbol may be delisted (period=7d)
# NXST: No price data found, symbol may be delisted (period=7d)
# PBPB: No price data found, symbol may be delisted (period=7d)
# ZPAS: No price data found, symbol may be delisted (period=7d)
# ICE: No price data found, symbol may be delisted (period=7d)
# VRN: No price data found, symbol may be delisted (period=7d)
# GCBC: No price data found, symbol may be delisted (period=7d)
# COMS: No price data found, symbol may be delisted (period=7d)
# SPGI: No price data found, symbol may be delisted (period=7d)
# TANH: No price data found, symbol may be delisted (period=7d)                       | 587/5185 [00:39<03:24, 22.46it/s]
# TSLA: No price data found, symbol may be delisted (period=7d)
# LGL: No price data found, symbol may be delisted (period=7d)
# XERS: No price data found, symbol may be delisted (period=7d)
# WTTR: No price data found, symbol may be delisted (period=7d)
# KTTA: No price data found, symbol may be delisted (period=7d)
# TYGO: No price data found, symbol may be delisted (period=7d)
# COFS: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'HMR' reason: Expecting value: line 1 column 1 (char 0)
# ALSAF: No price data found, symbol may be delisted (period=7d)
# RLGT: No price data found, symbol may be delisted (period=7d)
# CTSH: No price data found, symbol may be delisted (period=7d)
# CARV: No price data found, symbol may be delisted (period=7d)
# FBIZ: No price data found, symbol may be delisted (period=7d)                       | 597/5185 [00:39<03:27, 22.10it/s]
# SCHW: No price data found, symbol may be delisted (period=7d)
# EWTX: No price data found, symbol may be delisted (period=7d)
# ARIS: No price data found, symbol may be delisted (period=7d)
# GSM: No price data found, symbol may be delisted (period=7d)
# HMR: No price data found, symbol may be delisted (period=7d)
# HHH: No price data found, symbol may be delisted (period=7d)                        | 606/5185 [00:39<03:29, 21.88it/s]
# AXGN: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'VG' reason: Expecting value: line 1 column 1 (char 0)
# NTIOF: No price data found, symbol may be delisted (period=7d)
# SPFI: No price data found, symbol may be delisted (period=7d)
# CNA: No price data found, symbol may be delisted (period=7d)
# TBIO: No price data found, symbol may be delisted (period=7d)
# TRGP: No price data found, symbol may be delisted (period=7d)
# SMXT: No price data found, symbol may be delisted (period=7d)
# AGRO: No price data found, symbol may be delisted (period=7d)
# MATX: No price data found, symbol may be delisted (period=7d)
# Validation progress:  12%|██████▉                                                   | 615/5185 [00:40<03:33, 21.40it/s]Failed to get ticker 'GMHS' reason: Expecting value: line 1 column 1 (char 0)
# VG: No price data found, symbol may be delisted (period=7d)
# ...
# ORI: No price data found, symbol may be delisted (period=7d)
# WM: No price data found, symbol may be delisted (period=7d)█████████████████████▋  | 4977/5185 [04:48<00:15, 13.73it/s]
# BWXT: No price data found, symbol may be delisted (period=7d)
# LGMK: No price data found, symbol may be delisted (period=7d)
# BHE: No price data found, symbol may be delisted (period=7d)
# OCSL: No price data found, symbol may be delisted (period=7d)
# Validation progress:  96%|██████████████████████████████████████████████████████▊  | 4983/5185 [04:48<00:13, 14.53it/s]ODC: No price data found, symbol may be delisted (period=7d)
# IBTA: No price data found, symbol may be delisted (period=7d)
# ORMP: No price data found, symbol may be delisted (period=7d)
# ICON: No price data found, symbol may be delisted (period=7d)
# AMWL: No price data found, symbol may be delisted (period=7d)
# GMS: No price data found, symbol may be delisted (period=7d)
# ZIMV: No price data found, symbol may be delisted (period=7d)███████████████████▊  | 4989/5185 [04:49<00:12, 15.14it/s]
# TUSK: No price data found, symbol may be delisted (period=7d)
# BSGM: No price data found, symbol may be delisted (period=7d)
# ANSS: No price data found, symbol may be delisted (period=7d)
# TRNS: No price data found, symbol may be delisted (period=7d)███████████████████▉  | 4993/5185 [04:49<00:13, 14.20it/s]
# CNK: No price data found, symbol may be delisted (period=7d)
# SHCO: No price data found, symbol may be delisted (period=7d)
# ABL: No price data found, symbol may be delisted (period=7d)
# MNPR: No price data found, symbol may be delisted (period=7d)
# ARW: No price data found, symbol may be delisted (period=7d)
# Validation progress:  96%|██████████████████████████████████████████████████████▉  | 4999/5185 [04:50<00:12, 15.34it/s]STKS: No price data found, symbol may be delisted (period=7d)
# AXXDF: No price data found, symbol may be delisted (period=7d)
# OPAL: No price data found, symbol may be delisted (period=7d)
# FTDR: No price data found, symbol may be delisted (period=7d)
# DFS: No price data found, symbol may be delisted (period=7d)
# DSAQ: No price data found, symbol may be delisted (period=7d)
# CPSH: No price data found, symbol may be delisted (period=7d)███████████████████▉  | 5003/5185 [04:50<00:13, 13.70it/s]
# HFBL: No price data found, symbol may be delisted (period=7d)
# PRGO: No price data found, symbol may be delisted (period=7d)
# ACFN: No price data found, symbol may be delisted (period=7d)
# BHF: No price data found, symbol may be delisted (period=7d)
# GCI: No price data found, symbol may be delisted (period=7d)
# FULC: No price data found, symbol may be delisted (period=7d)
# DRRX: No price data found, symbol may be delisted (period=7d)████████████████████  | 5012/5185 [04:50<00:10, 16.59it/s]
# CAVA: No price data found, symbol may be delisted (period=7d)
# ARBE: No price data found, symbol may be delisted (period=7d)
# CHPT: No price data found, symbol may be delisted (period=7d)████████████████████  | 5014/5185 [04:51<00:12, 13.32it/s]
# HSHP: No price data found, symbol may be delisted (period=7d)
# PG: No price data found, symbol may be delisted (period=7d)
# ALYAF: No price data found, symbol may be delisted (period=7d)
# PAYO: No price data found, symbol may be delisted (period=7d)
# GITS: No price data found, symbol may be delisted (period=7d)
# NC: No price data found, symbol may be delisted (period=7d)
# PDEX: No price data found, symbol may be delisted (period=7d)████████████████████▏ | 5022/5185 [04:51<00:10, 15.83it/s]
# LPTX: No price data found, symbol may be delisted (period=7d)
# DY: No price data found, symbol may be delisted (period=7d)
# GLE: No price data found, symbol may be delisted (period=7d)█████████████████████▏ | 5025/5185 [04:51<00:11, 13.61it/s]
# RDNT: No price data found, symbol may be delisted (period=7d)
# PSTG: No price data found, symbol may be delisted (period=7d)
# DTST: No price data found, symbol may be delisted (period=7d)
# KRRO: No price data found, symbol may be delisted (period=7d)
# STI: No price data found, symbol may be delisted (period=7d)
# YTRA: No price data found, symbol may be delisted (period=7d)
# PFX: No price data found, symbol may be delisted (period=7d)█████████████████████▎ | 5032/5185 [04:52<00:09, 15.62it/s]
# CREX: No price data found, symbol may be delisted (period=7d)
# GROY: No price data found, symbol may be delisted (period=7d)
# VRNS: No price data found, symbol may be delisted (period=7d)
# YYAI: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'ALMU' reason: Expecting value: line 1 column 1 (char 0)████▎ | 5036/5185 [04:52<00:10, 13.89it/s]
# ACIU: No price data found, symbol may be delisted (period=7d)
# ALGS: No price data found, symbol may be delisted (period=7d)
# IIIV: No price data found, symbol may be delisted (period=7d)
# LTRPA: No price data found, symbol may be delisted (period=7d)
# GRAL: No price data found, symbol may be delisted (period=7d)
# DSUS: No price data found, symbol may be delisted (period=7d)
# ALMU: No price data found, symbol may be delisted (period=7d)████████████████████▍ | 5043/5185 [04:52<00:09, 15.61it/s]
# KOS: No price data found, symbol may be delisted (period=7d)
# LW: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'CYCU' reason: Expecting value: line 1 column 1 (char 0)
# RAIN: No price data found, symbol may be delisted (period=7d)
# FBYD: No price data found, symbol may be delisted (period=7d)
# TRC: No price data found, symbol may be delisted (period=7d)█████████████████████▍ | 5047/5185 [04:53<00:09, 14.01it/s]
# Failed to get ticker 'EHLD' reason: Expecting value: line 1 column 1 (char 0)
# AMED: No price data found, symbol may be delisted (period=7d)
# BNZI: No price data found, symbol may be delisted (period=7d)
# GLUE: No price data found, symbol may be delisted (period=7d)████████████████████▌ | 5051/5185 [04:53<00:09, 13.44it/s]
# WFG: No price data found, symbol may be delisted (period=7d)
# CYCU: No price data found, symbol may be delisted (period=7d)
# DUO: No price data found, symbol may be delisted (period=7d)
# QSI: No price data found, symbol may be delisted (period=7d)
# BEBE: No price data found, symbol may be delisted (period=7d)
# RSG: No price data found, symbol may be delisted (period=7d)█████████████████████▌ | 5056/5185 [04:54<00:10, 12.84it/s]
# SAVA: No price data found, symbol may be delisted (period=7d)
# CXW: No price data found, symbol may be delisted (period=7d)
# EHLD: No price data found, symbol may be delisted (period=7d)
# FMST: No price data found, symbol may be delisted (period=7d)
# AWX: No price data found, symbol may be delisted (period=7d)█████████████████████▋ | 5062/5185 [04:54<00:08, 14.04it/s]
# Failed to get ticker 'BHILQ' reason: Expecting value: line 1 column 1 (char 0)
# CHSN: No price data found, symbol may be delisted (period=7d)
# FLWS: No price data found, symbol may be delisted (period=7d)
# RR: No price data found, symbol may be delisted (period=7d)██████████████████████▋ | 5065/5185 [04:54<00:10, 11.75it/s]
# ALGM: No price data found, symbol may be delisted (period=7d)
# VHC: No price data found, symbol may be delisted (period=7d)
# VCNX: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'LAR' reason: Expecting value: line 1 column 1 (char 0)
# NAVB: No price data found, symbol may be delisted (period=7d)
# MAGN: No price data found, symbol may be delisted (period=7d)
# BHILQ: No price data found, symbol may be delisted (period=7d)
# PSIX: No price data found, symbol may be delisted (period=7d)████████████████████▊ | 5072/5185 [04:55<00:07, 14.21it/s]
# BJRI: No price data found, symbol may be delisted (period=7d)
# ELUT: No price data found, symbol may be delisted (period=7d)
# AMLX: No price data found, symbol may be delisted (period=7d)
# SIF: No price data found, symbol may be delisted (period=7d)
# ARCB: No price data found, symbol may be delisted (period=7d)████████████████████▊ | 5077/5185 [04:55<00:07, 14.21it/s]
# PSX: No price data found, symbol may be delisted (period=7d)
# LAR: No price data found, symbol may be delisted (period=7d)
# CXT: No price data found, symbol may be delisted (period=7d)
# GO: No price data found, symbol may be delisted (period=7d)
# KYMR: No price data found, symbol may be delisted (period=7d)
# HMPQ: No price data found, symbol may be delisted (period=7d)
# Validation progress:  98%|███████████████████████████████████████████████████████▉ | 5083/5185 [04:56<00:07, 13.52it/s]CPB: No price data found, symbol may be delisted (period=7d)
# AMG: No price data found, symbol may be delisted (period=7d)
# PKE: No price data found, symbol may be delisted (period=7d)
# CVKD: No price data found, symbol may be delisted (period=7d)
# MDB: No price data found, symbol may be delisted (period=7d)█████████████████████▉ | 5087/5185 [04:56<00:09, 10.27it/s]
# AMRK: No price data found, symbol may be delisted (period=7d)
# DOLE: No price data found, symbol may be delisted (period=7d)
# BBCP: No price data found, symbol may be delisted (period=7d)
# TPG: No price data found, symbol may be delisted (period=7d)
# HROW: No price data found, symbol may be delisted (period=7d)████████████████████▉ | 5093/5185 [04:57<00:08, 11.19it/s]
# YMAB: No price data found, symbol may be delisted (period=7d)
# LVWR: No price data found, symbol may be delisted (period=7d)
# ENLV: No price data found, symbol may be delisted (period=7d)
# CWT: No price data found, symbol may be delisted (period=7d)
# INDP: No price data found, symbol may be delisted (period=7d)
# WABC: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'AQUC' reason: Expecting value: line 1 column 1 (char 0)█████ | 5099/5185 [04:57<00:07, 12.14it/s]
# PBYI: No price data found, symbol may be delisted (period=7d)
# CTOR: No price data found, symbol may be delisted (period=7d)
# RDAC: No price data found, symbol may be delisted (period=7d)
# OPRX: No price data found, symbol may be delisted (period=7d)█████████████████████ | 5103/5185 [04:57<00:06, 11.82it/s]
# METCB: No price data found, symbol may be delisted (period=7d)
# ISTR: No price data found, symbol may be delisted (period=7d)
# WNS: No price data found, symbol may be delisted (period=7d)
# TMDX: No price data found, symbol may be delisted (period=7d)
# FVCB: No price data found, symbol may be delisted (period=7d)
# VRAYQ: No price data found, symbol may be delisted (period=7d)████████████████████▏| 5108/5185 [04:58<00:06, 12.15it/s]
# AQUC: No price data found, symbol may be delisted (period=7d)
# OSPN: No price data found, symbol may be delisted (period=7d)
# ZG: No price data found, symbol may be delisted (period=7d)
# SANG: No price data found, symbol may be delisted (period=7d)
# VGAS: No price data found, symbol may be delisted (period=7d)
# ELOX: No price data found, symbol may be delisted (period=7d)
# KZR: No price data found, symbol may be delisted (period=7d)
# RS: No price data found, symbol may be delisted (period=7d)
# INSP: No price data found, symbol may be delisted (period=7d)
# VIRT: No price data found, symbol may be delisted (period=7d)█████████████████████▎| 5118/5185 [04:58<00:04, 15.40it/s]
# NCPCF: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'SAIL' reason: Expecting value: line 1 column 1 (char 0)
# TTCM: No price data found, symbol may be delisted (period=7d)
# HQY: No price data found, symbol may be delisted (period=7d)
# BOW: No price data found, symbol may be delisted (period=7d)
# CPAY: No price data found, symbol may be delisted (period=7d)
# VVOS: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'LHSW' reason: Expecting value: line 1 column 1 (char 0)
# MRSN: No price data found, symbol may be delisted (period=7d)
# AFRM: No price data found, symbol may be delisted (period=7d)
# CCLD: No price data found, symbol may be delisted (period=7d)█████████████████████▎| 5127/5185 [04:59<00:03, 16.92it/s]
# PBFS: No price data found, symbol may be delisted (period=7d)
# FMNB: No price data found, symbol may be delisted (period=7d)
# BSRR: No price data found, symbol may be delisted (period=7d)
# PRM: No price data found, symbol may be delisted (period=7d)
# ORIS: No price data found, symbol may be delisted (period=7d)
# SAIL: No price data found, symbol may be delisted (period=7d)
# LHSW: No price data found, symbol may be delisted (period=7d)
# Validation progress:  99%|████████████████████████████████████████████████████████▍| 5136/5185 [04:59<00:02, 18.25it/s]ASIX: No price data found, symbol may be delisted (period=7d)
# HBB: No price data found, symbol may be delisted (period=7d)
# HUBB: No price data found, symbol may be delisted (period=7d)
# WWR: No price data found, symbol may be delisted (period=7d)
# GRCE: No price data found, symbol may be delisted (period=7d)
# AHCO: No price data found, symbol may be delisted (period=7d)
# INTT: No price data found, symbol may be delisted (period=7d)
# HNNA: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'FGMC' reason: Expecting value: line 1 column 1 (char 0)
# SATS: No price data found, symbol may be delisted (period=7d)
# PTPI: No price data found, symbol may be delisted (period=7d)█████████████████████▌| 5145/5185 [05:00<00:02, 18.94it/s]
# CRIS: No price data found, symbol may be delisted (period=7d)
# BNIX: No price data found, symbol may be delisted (period=7d)
# NHIQ: No price data found, symbol may be delisted (period=7d)
# MXL: No price data found, symbol may be delisted (period=7d)
# FGMC: No price data found, symbol may be delisted (period=7d)
# ZKIN: No price data found, symbol may be delisted (period=7d)
# IVRN: No price data found, symbol may be delisted (period=7d)
# GTIM: No price data found, symbol may be delisted (period=7d)
# FRME: No price data found, symbol may be delisted (period=7d)
# ESSA: No price data found, symbol may be delisted (period=7d)█████████████████████▋| 5155/5185 [05:00<00:01, 19.80it/s]
# LXRX: No price data found, symbol may be delisted (period=7d)
# CHGG: No price data found, symbol may be delisted (period=7d)
# FRST: No price data found, symbol may be delisted (period=7d)
# ZS: No price data found, symbol may be delisted (period=7d)
# MDNAF: No price data found, symbol may be delisted (period=7d)
# TK: No price data found, symbol may be delisted (period=7d)
# YIBO: No price data found, symbol may be delisted (period=7d)
# INSG: No price data found, symbol may be delisted (period=7d)
# NXGL: No price data found, symbol may be delisted (period=7d)
# MKDW: No price data found, symbol may be delisted (period=7d)
# VLY: No price data found, symbol may be delisted (period=7d)██████████████████████▊| 5165/5185 [05:01<00:00, 20.48it/s]
# AZTR: No price data found, symbol may be delisted (period=7d)
# LCFY: No price data found, symbol may be delisted (period=7d)
# GES: No price data found, symbol may be delisted (period=7d)
# NISN: No price data found, symbol may be delisted (period=7d)
# MNRO: No price data found, symbol may be delisted (period=7d)
# YELP: No price data found, symbol may be delisted (period=7d)
# SRM: No price data found, symbol may be delisted (period=7d)
# ELIQQ: No price data found, symbol may be delisted (period=7d)
# CLDI: No price data found, symbol may be delisted (period=7d)█████████████████████▉| 5175/5185 [05:01<00:00, 21.17it/s]
# AERT: No price data found, symbol may be delisted (period=7d)
# SABR: No price data found, symbol may be delisted (period=7d)
# BAC: No price data found, symbol may be delisted (period=7d)
# Failed to get ticker 'APTOF' reason: Expecting value: line 1 column 1 (char 0)
# EVTC: No price data found, symbol may be delisted (period=7d)
# BBIO: No price data found, symbol may be delisted (period=7d)
# CNVIF: No price data found, symbol may be delisted (period=7d)
# NPKI: No price data found, symbol may be delisted (period=7d)
# BHB: No price data found, symbol may be delisted (period=7d)
# APTOF: No price data found, symbol may be delisted (period=7d)
# Validation progress: 100%|█████████████████████████████████████████████████████████| 5185/5185 [05:01<00:00, 17.18it/s]
# ✅ Valid tickers: 0, ❌ Invalid tickers: 5185
# 💾 Saving results...
# 📁 Filtered tickers saved to validated_tickers.xlsx
# ✅ Done.

# %%
import pandas as pd
import yfinance as yf
import numpy as np
import time
import requests
from concurrent.futures import ThreadPoolExecutor
import yfinance.shared

# Create a custom session with a timeout
def set_request_timeout(timeout=10):
    session = requests.Session()
    session.request = lambda *args, **kwargs: requests.Session.request(session, *args, timeout=timeout, **kwargs)
    yfinance.shared._session = session

# Set the timeout for requests
set_request_timeout(10)

# Load validated tickers from Excel
def load_validated_tickers(file_path):
    try:
        df = pd.read_excel(file_path, sheet_name='Valid Tickers')
        return df['Valid Tickers'].tolist()
    except Exception as e:
        print(f"Error loading tickers from Excel: {e}")
        return []

# Batch download historical data in smaller chunks with retry logic and delays
def batch_download(tickers, period="1mo", batch_size=50, max_retries=3):
    all_data = []
    total_batches = len(tickers) // batch_size + (1 if len(tickers) % batch_size > 0 else 0)
    failed_tickers = []

    for i in range(0, len(tickers), batch_size):
        batch = tickers[i:i + batch_size]
        print(f"Downloading batch {i // batch_size + 1} of {total_batches}...")
        batch_failures = []
        for attempt in range(max_retries):
            try:
                data = yf.download(batch, period=period, group_by="ticker", threads=True, progress=False)
                all_data.append(data)
                break  # Exit retry loop on success
            except Exception as e:
                print(f"Attempt {attempt + 1} failed for batch {i // batch_size + 1}: {e}")
                time.sleep(2 ** attempt)  # Exponential backoff
                if attempt == max_retries - 1:  # If max retries reached
                    batch_failures.extend(batch)
        print(f"Batch {i // batch_size + 1} completed: {len(batch) - len(batch_failures)} successful, {len(batch_failures)} failed.")
        failed_tickers.extend(batch_failures)
        time.sleep(5)  # Delay between batches

    if failed_tickers:
        print(f"Failed to download data for {len(failed_tickers)} tickers.")
        save_failed_tickers(failed_tickers)

    if all_data:
        return pd.concat(all_data, axis=1)
    else:
        print("No data downloaded.")
        return None

# Save failed tickers to Excel
def save_failed_tickers(failed_tickers, file_name="failed_tickers.xlsx"):
    pd.DataFrame({'Failed Tickers': failed_tickers}).to_excel(file_name, index=False)
    print(f"Failed tickers saved to {file_name}")

# Filter tickers by liquidity
def filter_by_liquidity(data, min_volume=100000, min_dollar_volume=1000000):
    filtered_tickers = []
    for ticker in data.columns.get_level_values(0).unique():
        try:
            hist = data[ticker]
            avg_volume = hist['Volume'].mean()
            avg_dollar_volume = (hist['Close'] * hist['Volume']).mean()

            if avg_volume >= min_volume and avg_dollar_volume >= min_dollar_volume:
                filtered_tickers.append(ticker)
        except Exception as e:
            print(f"Liquidity check failed for {ticker}: {e}")

    print(f"Tickers after liquidity check: {len(filtered_tickers)}")
    return filtered_tickers

# Filter tickers by volatility
def filter_by_volatility(data, max_volatility=0.05):
    filtered_tickers = []
    for ticker in data.columns.get_level_values(0).unique():
        try:
            hist = data[ticker]
            returns = hist['Close'].pct_change()
            avg_volatility = returns.std()

            if avg_volatility <= max_volatility:
                filtered_tickers.append(ticker)
        except Exception as e:
            print(f"Volatility check failed for {ticker}: {e}")

    print(f"Tickers after volatility check: {len(filtered_tickers)}")
    return filtered_tickers

# Save filtered tickers to Excel
def save_filtered_tickers(filtered_tickers, output_file):
    filtered_df = pd.DataFrame({'Filtered Tickers': filtered_tickers})

    with pd.ExcelWriter(output_file) as writer:
        filtered_df.to_excel(writer, sheet_name='Filtered Tickers', index=False)

    print(f"Filtered tickers saved to {output_file}")

# Main function
def main():
    input_file = "validated_tickers.xlsx"  # Input file with validated tickers
    output_file = "filtered_tickers.xlsx"  # Output file for filtered tickers
    period = "1mo"  # Set your desired period
    batch_size = 50  # Number of tickers per batch

    print("Loading validated tickers...")
    tickers = load_validated_tickers(input_file)

    if not tickers:
        print("No validated tickers found. Exiting...")
        return

    print("Downloading historical data for tickers in batches...")
    data = batch_download(tickers, period=period, batch_size=batch_size)

    if data is None:
        print("Failed to download data. Exiting...")
        return

    print("Filtering by liquidity...")
    liquid_tickers = filter_by_liquidity(data)

    print("Filtering by volatility...")
    final_tickers = filter_by_volatility(data[liquid_tickers])

    print("Saving filtered tickers...")
    save_filtered_tickers(final_tickers, output_file)

if __name__ == "__main__":
    main()
# Out:
# Loading validated tickers...
# No validated tickers found. Exiting...
